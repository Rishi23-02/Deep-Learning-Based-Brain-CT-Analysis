# %%
# !pip install pydicom numpy scikit-image pillow scipy SimpleITK
# Out:
# Collecting pydicom
#   Using cached pydicom-3.0.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy in e:\anaconda3\lib\site-packages (2.3.5)
# Requirement already satisfied: scikit-image in e:\anaconda3\lib\site-packages (0.25.2)
# Requirement already satisfied: pillow in e:\anaconda3\lib\site-packages (12.0.0)
# Requirement already satisfied: scipy in e:\anaconda3\lib\site-packages (1.16.3)
# Collecting SimpleITK
#   Using cached simpleitk-2.5.3-cp311-abi3-win_amd64.whl.metadata (7.3 kB)
# Requirement already satisfied: networkx>=3.0 in e:\anaconda3\lib\site-packages (from scikit-image) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in e:\anaconda3\lib\site-packages (from scikit-image) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in e:\anaconda3\lib\site-packages (from scikit-image) (2025.10.4)
# Requirement already satisfied: packaging>=21 in e:\anaconda3\lib\site-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in e:\anaconda3\lib\site-packages (from scikit-image) (0.4)
# Using cached pydicom-3.0.1-py3-none-any.whl (2.4 MB)
# Using cached simpleitk-2.5.3-cp311-abi3-win_amd64.whl (18.8 MB)
# Installing collected packages: SimpleITK, pydicom
#
#    ---------------------------------------- 0/2 [SimpleITK]
#    ---------------------------------------- 0/2 [SimpleITK]
#    ---------------------------------------- 0/2 [SimpleITK]
#    ---------------------------------------- 0/2 [SimpleITK]
#    -------------------- ------------------- 1/2 [pydicom]
#    -------------------- ------------------- 1/2 [pydicom]
#    -------------------- ------------------- 1/2 [pydicom]
#    -------------------- ------------------- 1/2 [pydicom]
#    -------------------- ------------------- 1/2 [pydicom]
#    -------------------- ------------------- 1/2 [pydicom]
#    -------------------- ------------------- 1/2 [pydicom]
#    -------------------- ------------------- 1/2 [pydicom]
#    -------------------- ------------------- 1/2 [pydicom]
#    -------------------- ------------------- 1/2 [pydicom]
#    -------------------- ------------------- 1/2 [pydicom]
#    -------------------- ------------------- 1/2 [pydicom]
#    ---------------------------------------- 2/2 [pydicom]
#
# Successfully installed SimpleITK-2.5.3 pydicom-3.0.1

# %%
import os  # For file/directory operations (e.g., listing files, creating dirs). What: System interaction module. Why: To handle batch processing of files in a directory. How useful: Automates working with multiple DICOM files without hardcoding paths.
import pydicom  # For reading DICOM files. What: Library for DICOM parsing. Why: DICOMs have metadata and pixels; this extracts them safely. How useful: Ensures accurate HU conversion and handles medical-specific formats.
import numpy as np  # For array math. What: Numerical computing library. Why: Images are arrays; needed for clipping, scaling. How useful: Fast, vectorized operations prevent slow loops, ideal for large images.
import SimpleITK as sitk  # For advanced image processing (not used here, but potential for extensions like registration). What: ITK wrapper. Why: Future-proofing; skipped in this basic script. How useful: For complex tasks like 3D handling if expanded.
from PIL import Image  # For image saving. What: Pillow's Image class. Why: Converts arrays to PNG for output. How useful: Enables easy visualization/storage in web-friendly formats.
from skimage import filters, morphology  # Filters (e.g., Otsu, median), morphology (e.g., disk, opening). What: Image processing submodules. Why: For thresholding, denoising, structuring elements. How useful: Provides ready-made algorithms for noise reduction and shape manipulation without custom code.

# %%
def save_as_png(array, path):
    """Utility to save a numpy array as a normalized PNG."""
    # What: Function to normalize and save array as PNG, handling binary or intensity data.
    # Why: Arrays need scaling to 0-255 for image formats; handles different types.
    # How useful: Ensures consistent visualization; binary masks become visible (white/black).
    
    # Handle both binary masks and intensity images
    # What: Checks dtype and normalizes accordingly.
    # Why: Masks (bool) need conversion; intensities may vary in range.
    # How useful: Versatile for all steps; prevents save errors on non-uint8 data.
    if array.dtype == bool:
        img_array = (array * 255).astype(np.uint8)
    else:
        # Standardize range to 0-255 for visualization
        # What: Min-max normalization to [0,255].
        # Why: Raw HU/values may be wide; this fits PNG range.
        # How useful: Makes images displayable; handles uniform arrays gracefully.
        amin = array.min()
        amax = array.max()
        if amax > amin:
            img_array = ((array - amin) / (amax - amin) * 255).astype(np.uint8)
        else:
            img_array = np.zeros_like(array, dtype=np.uint8)
    
    img = Image.fromarray(img_array)  # Converts to PIL Image.
    img.save(path)  # Saves to path.

# %%
def process_all_steps():
    # What: Batch function to process DICOMs, saving each preprocessing/segmentation step as PNG in subfolders.
    # Why: Visualizes pipeline progression; organizes outputs.
    # How useful: Easy inspection of intermediates; aids debugging/understanding effects.
    
    input_dir = "E:/Normal/DICOM"  # Input path; adjust to your DICOM folder (e.g., 'D:/CT_Dataset/Normal').
    base_output_dir = "E:/Normal/preprocessing_steps"  # Base output; subfolders per step.
    
    # Define the steps we want to save
    # What: List of step names for subfolders.
    # Why: Structures outputs (e.g., '1_Raw', '6_Final_Stripped').
    # How useful: Clear organization; matches your described sequence.
    steps = [
        "1_Raw",
        "2_HU_Normalized",
        "3_Windowed",
        "4_Denoised",
        "5_Skull_Mask",
        "6_Final_Stripped"
    ]
    
    for step in steps:
        os.makedirs(os.path.join(base_output_dir, step), exist_ok=True)  # Creates subfolders.
    
    files = [f for f in os.listdir(input_dir) if f.endswith('.dcm')]  # Lists DICOMs.
    print(f"Processing {len(files)} files into individual steps...")
    
    for f in files:
        try:
            file_path = os.path.join(input_dir, f)
            filename_base = f.replace('.dcm', '.png')
            
            # Step 1: Raw
            # What: Loads and saves original pixels.
            # Why: Baseline for comparison.
            # How useful: Shows unprocessed state; highlights later improvements.
            ds = pydicom.dcmread(file_path)
            raw_pixel = ds.pixel_array
            save_as_png(raw_pixel, os.path.join(base_output_dir, "1_Raw", filename_base))
            
            # Step 2: HU Normalized
            # What: Applies slope/intercept for HU conversion.
            # Why: Standardizes densities (e.g., air=-1000 HU).
            # How useful: Quantitative; enables tissue-specific analysis.
            slope = float(ds.RescaleSlope) if 'RescaleSlope' in ds else 1
            intercept = float(ds.RescaleIntercept) if 'RescaleIntercept' in ds else 0
            hu_image = raw_pixel * slope + intercept
            save_as_png(hu_image, os.path.join(base_output_dir, "2_HU_Normalized", filename_base))
            
            # Step 3: Windowing (Brain Window)
            # What: Clips HU to brain range (0-80 HU).
            # Why: Enhances soft tissue contrast.
            # How useful: Suppresses bone; focuses on brain for better visuals.
            window_center = 40
            window_width = 80
            min_val = window_center - (window_width / 2)
            max_val = window_center + (window_width / 2)
            windowed = np.clip(hu_image, min_val, max_val)
            save_as_png(windowed, os.path.join(base_output_dir, "3_Windowed", filename_base))
            
            # Step 4: Denoised
            # What: Median filter on normalized windowed image.
            # Why: Reduces noise post-windowing.
            # How useful: Smoother image; improves segmentation accuracy.
            # Normalize to 0-255 first for standard filter behavior
            norm_for_filter = ((windowed - min_val) / (max_val - min_val) * 255).astype(np.uint8)
            denoised = filters.median(norm_for_filter, morphology.disk(1))
            save_as_png(denoised, os.path.join(base_output_dir, "4_Denoised", filename_base))
            
            # Step 5: Skull Mask
            # What: Binary mask from thresholding/morphology.
            # Why: Identifies brain region.
            # How useful: Visualizes isolation; precursor to stripping.
            thresh = filters.threshold_otsu(denoised)
            binary = denoised > thresh
            from skimage.segmentation import clear_border
            bw = clear_border(binary)
            selem = morphology.disk(2)
            opened = morphology.opening(bw, selem)
            
            from skimage.measure import label, regionprops
            label_img = label(opened)
            props = regionprops(label_img)
            if props:
                largest_region = max(props, key=lambda x: x.area)
                mask = label_img == largest_region.label
                from scipy import ndimage as ndi
                mask = ndi.binary_fill_holes(mask)
                mask = morphology.dilation(mask, morphology.disk(3))
            else:
                mask = np.ones_like(denoised, dtype=bool)
                
            save_as_png(mask, os.path.join(base_output_dir, "5_Skull_Mask", filename_base))
            
            # Step 6: Final Stripped
            # What: Applies mask to denoised image.
            # Why: Removes skull for brain-only view.
            # How useful: Clean input for DL; focuses on intracranial features.
            final = denoised * mask
            save_as_png(final, os.path.join(base_output_dir, "6_Final_Stripped", filename_base))
            
        except Exception as e:
            print(f"Error processing {f}: {e}")

# %%
# Cell 1: Imports and Setup
import os  # For directory operations and file handling. What: Manages paths and creates folders. Why better: Built-in, no extra deps; more reliable than manual string manipulation for cross-OS compatibility.
from PIL import Image  # For image loading and resizing. What: Handles image I/O and transformations. Why better: Lightweight and efficient for PNG/JPG; faster than OpenCV for simple tasks, no unnecessary features.
import numpy as np  # For array operations if needed. What: Numerical computations. Why better: Vectorized ops are faster than loops; essential if extending to batch processing.

# Define directories
processed_dir = 'E:/Normal/preprocessing_steps/6_Final_Stripped'  # Input: Where preprocessed images are stored. What: Source path. Why better: Centralized; easy to change without code edits.
lr_dir = 'E:/Normal/train_lr'  # Output for low-res images. What: LR storage. Why better: Organized subdirs prevent clutter; follows standard SR dataset structure.
hr_dir = 'E:/Normal/train_hr'  # Output for high-res (original processed). What: HR storage. Why better: Pairs with LR for easy loading in training.

os.makedirs(lr_dir, exist_ok=True)  # Creates LR dir if missing. What: Ensures dir exists. Why better: 'exist_ok' avoids errors; safer than manual checks.
os.makedirs(hr_dir, exist_ok=True)  # Same for HR. What: Dir creation. Why better: Consistent handling; prevents runtime failures.

# %%
# Run the batch function.
process_all_steps()  # Executes on all files in input_dir, saving steps as PNGs.
# Out:
# Processing 4427 files into individual steps...

# %%
# Cell 2: Create LR-HR Pairs Function
def create_lr_hr_pairs(processed_dir, lr_dir, hr_dir, scale_factor=4):
    # What: Function to generate LR from HR by downsampling and save pairs.
    # Why better: Modular; reusable. Downsampling simulates real LR; better than random noise as it mimics acquisition degradation.
    
    files = [f for f in os.listdir(processed_dir) if f.endswith('.png')]  # Lists PNGs. What: Filters images. Why better: Specific extension avoids non-images; list comp is concise/Pythonic over loops.
    print(f"Found {len(files)} processed images.")  # Logs count. What: User feedback. Why better: Helps debug; simple print over complex logging for this script.
    
    for f in files:  # Loops over files. What: Processes each. Why better: Sequential for simplicity; parallelizable if needed, but overkill for small datasets.
        hr_path = os.path.join(processed_dir, f)  # Full HR path. What: Constructs path. Why better: os.path.join handles OS differences; safer than '/' concatenation.
        hr_img = Image.open(hr_path)  # Loads HR image. What: Opens as PIL Image. Why better: PIL preserves quality; easier than numpy for resizing.
        
        # Create LR by downsampling
        lr_size = (hr_img.width // scale_factor, hr_img.height // scale_factor)  # Computes LR dimensions. What: Integer division for downscale. Why better: Ensures integer sizes; avoids float errors in resizing.
        lr_img = hr_img.resize(lr_size, Image.BICUBIC)  # Resizes with bicubic. What: Downsamples. Why better: Bicubic preserves details better than bilinear/nearest; standard for SR simulation.
        
        # Save LR and HR
        lr_save = os.path.join(lr_dir, f)  # LR save path. What: Same filename for pairing. Why better: Easy matching; no renaming needed.
        hr_save = os.path.join(hr_dir, f)  # HR save path. What: Copies original. Why better: Keeps HR intact; allows direct comparison.
        lr_img.save(lr_save)  # Saves LR. What: PNG export. Why better: Lossless; maintains quality over JPG compression.
        hr_img.save(hr_save)  # Saves HR. What: Copies to HR dir. Why better: Centralizes pairs; avoids reading from processed_dir later.
        
        print(f"Created pair for {f}")  # Logs progress. What: Feedback per file. Why better: Tracks completion; useful for large sets.

# %%
# Cell 3: Run the Function
create_lr_hr_pairs(processed_dir, lr_dir, hr_dir, scale_factor=4)  # Executes with 4x scale. What: Calls function. Why better: 4x is common in SR; adjustable param for flexibility.
# After running, check lr_dir and hr_dir for pairs. Each LR is downsampled version of HR; used for training super-resolution models.
# Out:
# Found 4427 processed images.
# Created pair for 10000.png
# Created pair for 10001.png
# Created pair for 10004.png
# Created pair for 10005.png
# Created pair for 10006.png
# Created pair for 10008.png
# Created pair for 10009.png
# Created pair for 10010.png
# Created pair for 10011.png
# Created pair for 10012.png
# Created pair for 10013.png
# Created pair for 10014.png
# Created pair for 10015.png
# Created pair for 10016.png
# Created pair for 10018.png
# Created pair for 10019.png
# Created pair for 10021.png
# Created pair for 10022.png
# Created pair for 10023.png
# Created pair for 10025.png
# Created pair for 10026.png
# Created pair for 10027.png
# Created pair for 10030.png
# Created pair for 10032.png
# Created pair for 10034.png
# Created pair for 10035.png
# Created pair for 10037.png
# Created pair for 10040.png
# Created pair for 10041.png
# Created pair for 10042.png
# Created pair for 10043.png
# Created pair for 10044.png
# Created pair for 10048.png
# Created pair for 10051.png
# Created pair for 10054.png
# Created pair for 10055.png
# Created pair for 10056.png
# Created pair for 10057.png
# Created pair for 10058.png
# Created pair for 10061.png
# Created pair for 10065.png
# Created pair for 10066.png
# Created pair for 10069.png
# Created pair for 10070.png
# Created pair for 10071.png
# Created pair for 10074.png
# Created pair for 10076.png
# Created pair for 10079.png
# Created pair for 10080.png
# Created pair for 10081.png
# Created pair for 10082.png
# Created pair for 10083.png
# Created pair for 10084.png
# Created pair for 10085.png
# Created pair for 10086.png
# Created pair for 10087.png
# Created pair for 10089.png
# Created pair for 10090.png
# Created pair for 10091.png
# Created pair for 10092.png
# Created pair for 10093.png
# Created pair for 10096.png
# Created pair for 10097.png
# Created pair for 10098.png
# Created pair for 10099.png
# Created pair for 10100.png
# Created pair for 10102.png
# Created pair for 10103.png
# Created pair for 10104.png
# Created pair for 10106.png
# Created pair for 10107.png
# Created pair for 10109.png
# Created pair for 10111.png
# Created pair for 10112.png
# Created pair for 10114.png
# Created pair for 10115.png
# Created pair for 10117.png
# Created pair for 10118.png
# Created pair for 10119.png
# Created pair for 10121.png
# Created pair for 10122.png
# Created pair for 10124.png
# Created pair for 10125.png
# Created pair for 10127.png
# Created pair for 10128.png
# Created pair for 10129.png
# Created pair for 10130.png
# Created pair for 10131.png
# Created pair for 10132.png
# Created pair for 10133.png
# Created pair for 10135.png
# Created pair for 10136.png
# Created pair for 10137.png
# Created pair for 10138.png
# Created pair for 10139.png
# Created pair for 10140.png
# Created pair for 10141.png
# Created pair for 10142.png
# Created pair for 10144.png
# Created pair for 10148.png
# Created pair for 10149.png
# Created pair for 10152.png
# Created pair for 10157.png
# Created pair for 10159.png
# Created pair for 10161.png
# Created pair for 10162.png
# Created pair for 10163.png
# Created pair for 10165.png
# Created pair for 10166.png
# Created pair for 10167.png
# Created pair for 10168.png
# Created pair for 10169.png
# Created pair for 10170.png
# Created pair for 10171.png
# Created pair for 10173.png
# Created pair for 10174.png
# Created pair for 10175.png
# Created pair for 10176.png
# Created pair for 10177.png
# Created pair for 10178.png
# Created pair for 10180.png
# Created pair for 10182.png
# Created pair for 10183.png
# Created pair for 10184.png
# Created pair for 10185.png
# Created pair for 10186.png
# Created pair for 10191.png
# Created pair for 10193.png
# Created pair for 10195.png
# Created pair for 10196.png
# Created pair for 10197.png
# Created pair for 10198.png
# Created pair for 10199.png
# Created pair for 10201.png
# Created pair for 10204.png
# Created pair for 10205.png
# Created pair for 10207.png
# Created pair for 10208.png
# Created pair for 10211.png
# Created pair for 10212.png
# Created pair for 10213.png
# Created pair for 10215.png
# Created pair for 10216.png
# Created pair for 10217.png
# Created pair for 10218.png
# Created pair for 10219.png
# Created pair for 10220.png
# Created pair for 10221.png
# Created pair for 10224.png
# Created pair for 10225.png
# Created pair for 10226.png
# Created pair for 10228.png
# Created pair for 10229.png
# Created pair for 10232.png
# Created pair for 10233.png
# Created pair for 10235.png
# Created pair for 10237.png
# Created pair for 10239.png
# Created pair for 10240.png
# Created pair for 10243.png
# Created pair for 10244.png
# Created pair for 10246.png
# Created pair for 10247.png
# Created pair for 10249.png
# Created pair for 10251.png
# Created pair for 10252.png
# Created pair for 10254.png
# Created pair for 10255.png
# Created pair for 10256.png
# Created pair for 10257.png
# Created pair for 10259.png
# Created pair for 10260.png
# Created pair for 10264.png
# Created pair for 10266.png
# Created pair for 10269.png
# Created pair for 10270.png
# Created pair for 10272.png
# Created pair for 10274.png
# Created pair for 10275.png
# Created pair for 10277.png
# Created pair for 10279.png
# Created pair for 10281.png
# Created pair for 10282.png
# Created pair for 10283.png
# Created pair for 10284.png
# Created pair for 10286.png
# Created pair for 10287.png
# Created pair for 10288.png
# Created pair for 10291.png
# Created pair for 10292.png
# Created pair for 10293.png
# Created pair for 10294.png
# Created pair for 10295.png
# Created pair for 10299.png
# Created pair for 10302.png
# Created pair for 10303.png
# Created pair for 10304.png
# Created pair for 10306.png
# Created pair for 10308.png
# Created pair for 10311.png
# Created pair for 10312.png
# Created pair for 10313.png
# Created pair for 10314.png
# Created pair for 10315.png
# Created pair for 10316.png
# Created pair for 10318.png
# Created pair for 10321.png
# Created pair for 10322.png
# Created pair for 10324.png
# Created pair for 10325.png
# Created pair for 10326.png
# Created pair for 10333.png
# Created pair for 10334.png
# Created pair for 10335.png
# Created pair for 10336.png
# Created pair for 10337.png
# Created pair for 10338.png
# Created pair for 10339.png
# Created pair for 10340.png
# Created pair for 10341.png
# Created pair for 10342.png
# Created pair for 10343.png
# Created pair for 10344.png
# Created pair for 10345.png
# Created pair for 10347.png
# Created pair for 10348.png
# Created pair for 10349.png
# Created pair for 10352.png
# Created pair for 10353.png
# Created pair for 10357.png
# Created pair for 10358.png
# Created pair for 10359.png
# Created pair for 10361.png
# Created pair for 10365.png
# Created pair for 10366.png
# Created pair for 10368.png
# Created pair for 10369.png
# Created pair for 10370.png
# Created pair for 10371.png
# Created pair for 10373.png
# Created pair for 10374.png
# Created pair for 10375.png
# Created pair for 10376.png
# Created pair for 10379.png
# Created pair for 10380.png
# Created pair for 10381.png
# Created pair for 10382.png
# Created pair for 10383.png
# Created pair for 10384.png
# Created pair for 10385.png
# Created pair for 10386.png
# Created pair for 10387.png
# Created pair for 10389.png
# Created pair for 10390.png
# Created pair for 10392.png
# Created pair for 10393.png
# Created pair for 10396.png
# Created pair for 10398.png
# Created pair for 10400.png
# Created pair for 10401.png
# Created pair for 10402.png
# Created pair for 10405.png
# Created pair for 10406.png
# Created pair for 10407.png
# Created pair for 10408.png
# Created pair for 10409.png
# Created pair for 10411.png
# Created pair for 10412.png
# Created pair for 10413.png
# Created pair for 10414.png
# Created pair for 10416.png
# Created pair for 10417.png
# Created pair for 10419.png
# Created pair for 10421.png
# Created pair for 10422.png
# Created pair for 10423.png
# Created pair for 10424.png
# Created pair for 10425.png
# Created pair for 10426.png
# Created pair for 10427.png
# Created pair for 10428.png
# Created pair for 10429.png
# Created pair for 10431.png
# Created pair for 10433.png
# Created pair for 10439.png
# Created pair for 10441.png
# Created pair for 10443.png
# Created pair for 10445.png
# Created pair for 10450.png
# Created pair for 10451.png
# Created pair for 10452.png
# Created pair for 10454.png
# Created pair for 10455.png
# Created pair for 10456.png
# Created pair for 10457.png
# Created pair for 10458.png
# Created pair for 10462.png
# Created pair for 10463.png
# Created pair for 10465.png
# Created pair for 10469.png
# Created pair for 10470.png
# Created pair for 10471.png
# Created pair for 10472.png
# Created pair for 10473.png
# Created pair for 10474.png
# Created pair for 10478.png
# Created pair for 10480.png
# Created pair for 10482.png
# Created pair for 10483.png
# Created pair for 10484.png
# Created pair for 10490.png
# Created pair for 10491.png
# Created pair for 10492.png
# Created pair for 10495.png
# Created pair for 10496.png
# Created pair for 10497.png
# Created pair for 10498.png
# Created pair for 10500.png
# Created pair for 10502.png
# Created pair for 10503.png
# Created pair for 10504.png
# Created pair for 10505.png
# Created pair for 10506.png
# Created pair for 10508.png
# Created pair for 10511.png
# Created pair for 10512.png
# Created pair for 10514.png
# Created pair for 10515.png
# Created pair for 10516.png
# Created pair for 10517.png
# Created pair for 10520.png
# Created pair for 10521.png
# Created pair for 10523.png
# Created pair for 10524.png
# Created pair for 10526.png
# Created pair for 10527.png
# Created pair for 10529.png
# Created pair for 10530.png
# Created pair for 10531.png
# Created pair for 10533.png
# Created pair for 10534.png
# Created pair for 10535.png
# Created pair for 10536.png
# Created pair for 10537.png
# Created pair for 10540.png
# Created pair for 10541.png
# Created pair for 10543.png
# Created pair for 10544.png
# Created pair for 10545.png
# Created pair for 10546.png
# Created pair for 10548.png
# Created pair for 10550.png
# Created pair for 10551.png
# Created pair for 10552.png
# Created pair for 10553.png
# Created pair for 10554.png
# Created pair for 10556.png
# Created pair for 10557.png
# Created pair for 10558.png
# Created pair for 10559.png
# Created pair for 10562.png
# Created pair for 10564.png
# Created pair for 10565.png
# Created pair for 10566.png
# Created pair for 10569.png
# Created pair for 10570.png
# Created pair for 10571.png
# Created pair for 10572.png
# Created pair for 10573.png
# Created pair for 10574.png
# Created pair for 10576.png
# Created pair for 10577.png
# Created pair for 10578.png
# Created pair for 10580.png
# Created pair for 10581.png
# Created pair for 10582.png
# Created pair for 10584.png
# Created pair for 10585.png
# Created pair for 10587.png
# Created pair for 10588.png
# Created pair for 10589.png
# Created pair for 10590.png
# Created pair for 10591.png
# Created pair for 10592.png
# Created pair for 10593.png
# Created pair for 10596.png
# Created pair for 10597.png
# Created pair for 10598.png
# Created pair for 10601.png
# Created pair for 10604.png
# Created pair for 10606.png
# Created pair for 10607.png
# Created pair for 10608.png
# Created pair for 10609.png
# Created pair for 10610.png
# Created pair for 10612.png
# Created pair for 10614.png
# Created pair for 10615.png
# Created pair for 10616.png
# Created pair for 10617.png
# Created pair for 10619.png
# Created pair for 10620.png
# Created pair for 10621.png
# Created pair for 10623.png
# Created pair for 10624.png
# Created pair for 10625.png
# Created pair for 10626.png
# Created pair for 10628.png
# Created pair for 10629.png
# Created pair for 10630.png
# Created pair for 10631.png
# Created pair for 10632.png
# Created pair for 10634.png
# Created pair for 10636.png
# Created pair for 10638.png
# Created pair for 10639.png
# Created pair for 10640.png
# Created pair for 10643.png
# Created pair for 10646.png
# Created pair for 10647.png
# Created pair for 10651.png
# Created pair for 10652.png
# Created pair for 10653.png
# Created pair for 10654.png
# Created pair for 10655.png
# Created pair for 10656.png
# Created pair for 10658.png
# Created pair for 10659.png
# Created pair for 10661.png
# Created pair for 10663.png
# Created pair for 10664.png
# Created pair for 10665.png
# Created pair for 10666.png
# Created pair for 10667.png
# Created pair for 10668.png
# Created pair for 10669.png
# Created pair for 10672.png
# Created pair for 10673.png
# Created pair for 10674.png
# Created pair for 10675.png
# Created pair for 10678.png
# Created pair for 10679.png
# Created pair for 10680.png
# Created pair for 10681.png
# Created pair for 10683.png
# Created pair for 10684.png
# Created pair for 10686.png
# Created pair for 10692.png
# Created pair for 10695.png
# Created pair for 10698.png
# Created pair for 10699.png
# Created pair for 10700.png
# Created pair for 10704.png
# Created pair for 10706.png
# Created pair for 10707.png
# Created pair for 10708.png
# Created pair for 10709.png
# Created pair for 10710.png
# Created pair for 10711.png
# Created pair for 10717.png
# Created pair for 10718.png
# Created pair for 10720.png
# Created pair for 10721.png
# Created pair for 10722.png
# Created pair for 10723.png
# Created pair for 10724.png
# Created pair for 10725.png
# Created pair for 10727.png
# Created pair for 10728.png
# Created pair for 10731.png
# Created pair for 10732.png
# Created pair for 10733.png
# Created pair for 10735.png
# Created pair for 10738.png
# Created pair for 10739.png
# Created pair for 10740.png
# Created pair for 10741.png
# Created pair for 10744.png
# Created pair for 10746.png
# Created pair for 10748.png
# Created pair for 10749.png
# Created pair for 10750.png
# Created pair for 10751.png
# Created pair for 10752.png
# Created pair for 10753.png
# Created pair for 10756.png
# Created pair for 10759.png
# Created pair for 10760.png
# Created pair for 10762.png
# Created pair for 10763.png
# Created pair for 10764.png
# Created pair for 10768.png
# Created pair for 10772.png
# Created pair for 10773.png
# Created pair for 10774.png
# Created pair for 10775.png
# Created pair for 10776.png
# Created pair for 10778.png
# Created pair for 10779.png
# Created pair for 10780.png
# Created pair for 10781.png
# Created pair for 10782.png
# Created pair for 10784.png
# Created pair for 10790.png
# Created pair for 10792.png
# Created pair for 10794.png
# Created pair for 10798.png
# Created pair for 10799.png
# Created pair for 10800.png
# Created pair for 10801.png
# Created pair for 10802.png
# Created pair for 10803.png
# Created pair for 10805.png
# Created pair for 10807.png
# Created pair for 10810.png
# Created pair for 10811.png
# Created pair for 10812.png
# Created pair for 10813.png
# Created pair for 10817.png
# Created pair for 10818.png
# Created pair for 10819.png
# Created pair for 10821.png
# Created pair for 10822.png
# Created pair for 10823.png
# Created pair for 10824.png
# Created pair for 10825.png
# Created pair for 10826.png
# Created pair for 10827.png
# Created pair for 10828.png
# Created pair for 10829.png
# Created pair for 10834.png
# Created pair for 10835.png
# Created pair for 10836.png
# Created pair for 10837.png
# Created pair for 10838.png
# Created pair for 10839.png
# Created pair for 10840.png
# Created pair for 10841.png
# Created pair for 10842.png
# Created pair for 10843.png
# Created pair for 10844.png
# Created pair for 10847.png
# Created pair for 10848.png
# Created pair for 10849.png
# Created pair for 10851.png
# Created pair for 10854.png
# Created pair for 10855.png
# Created pair for 10856.png
# Created pair for 10857.png
# Created pair for 10860.png
# Created pair for 10861.png
# Created pair for 10862.png
# Created pair for 10863.png
# Created pair for 10864.png
# Created pair for 10869.png
# Created pair for 10873.png
# Created pair for 10874.png
# Created pair for 10879.png
# Created pair for 10880.png
# Created pair for 10881.png
# Created pair for 10882.png
# Created pair for 10885.png
# Created pair for 10886.png
# Created pair for 10891.png
# Created pair for 10892.png
# Created pair for 10895.png
# Created pair for 10896.png
# Created pair for 10897.png
# Created pair for 10899.png
# Created pair for 10900.png
# Created pair for 10902.png
# Created pair for 10903.png
# Created pair for 10904.png
# Created pair for 10905.png
# Created pair for 10906.png
# Created pair for 10909.png
# Created pair for 10912.png
# Created pair for 10913.png
# Created pair for 10914.png
# Created pair for 10915.png
# Created pair for 10916.png
# Created pair for 10919.png
# Created pair for 10922.png
# Created pair for 10929.png
# Created pair for 10930.png
# Created pair for 10932.png
# Created pair for 10935.png
# Created pair for 10938.png
# Created pair for 10939.png
# Created pair for 10940.png
# Created pair for 10942.png
# Created pair for 10944.png
# Created pair for 10945.png
# Created pair for 10946.png
# Created pair for 10947.png
# Created pair for 10948.png
# Created pair for 10949.png
# Created pair for 10950.png
# Created pair for 10953.png
# Created pair for 10957.png
# Created pair for 10964.png
# Created pair for 10966.png
# Created pair for 10968.png
# Created pair for 10969.png
# Created pair for 10970.png
# Created pair for 10971.png
# Created pair for 10972.png
# Created pair for 10973.png
# Created pair for 10974.png
# Created pair for 10976.png
# Created pair for 10978.png
# Created pair for 10979.png
# Created pair for 10982.png
# Created pair for 10983.png
# Created pair for 10988.png
# Created pair for 10991.png
# Created pair for 10993.png
# Created pair for 10994.png
# Created pair for 10995.png
# Created pair for 10996.png
# Created pair for 10998.png
# Created pair for 10999.png
# Created pair for 11000.png
# Created pair for 11001.png
# Created pair for 11002.png
# Created pair for 11003.png
# Created pair for 11005.png
# Created pair for 11006.png
# Created pair for 11009.png
# Created pair for 11011.png
# Created pair for 11012.png
# Created pair for 11013.png
# Created pair for 11014.png
# Created pair for 11017.png
# Created pair for 11018.png
# Created pair for 11022.png
# Created pair for 11024.png
# Created pair for 11025.png
# Created pair for 11026.png
# Created pair for 11027.png
# Created pair for 11029.png
# Created pair for 11030.png
# Created pair for 11031.png
# Created pair for 11032.png
# Created pair for 11034.png
# Created pair for 11035.png
# Created pair for 11037.png
# Created pair for 11038.png
# Created pair for 11040.png
# Created pair for 11042.png
# Created pair for 11043.png
# Created pair for 11044.png
# Created pair for 11045.png
# Created pair for 11047.png
# Created pair for 11050.png
# Created pair for 11051.png
# Created pair for 11053.png
# Created pair for 11054.png
# Created pair for 11056.png
# Created pair for 11057.png
# Created pair for 11058.png
# Created pair for 11060.png
# Created pair for 11062.png
# Created pair for 11063.png
# Created pair for 11064.png
# Created pair for 11066.png
# Created pair for 11067.png
# Created pair for 11068.png
# Created pair for 11069.png
# Created pair for 11070.png
# Created pair for 11071.png
# Created pair for 11073.png
# Created pair for 11075.png
# Created pair for 11076.png
# Created pair for 11077.png
# Created pair for 11078.png
# Created pair for 11079.png
# Created pair for 11080.png
# Created pair for 11081.png
# Created pair for 11082.png
# Created pair for 11083.png
# Created pair for 11084.png
# Created pair for 11085.png
# Created pair for 11087.png
# Created pair for 11088.png
# Created pair for 11089.png
# Created pair for 11092.png
# Created pair for 11093.png
# Created pair for 11094.png
# Created pair for 11095.png
# Created pair for 11096.png
# Created pair for 11097.png
# Created pair for 11098.png
# Created pair for 11099.png
# Created pair for 11100.png
# Created pair for 11102.png
# Created pair for 11105.png
# Created pair for 11107.png
# Created pair for 11108.png
# Created pair for 11109.png
# Created pair for 11110.png
# Created pair for 11111.png
# Created pair for 11116.png
# Created pair for 11120.png
# Created pair for 11121.png
# Created pair for 11122.png
# Created pair for 11125.png
# Created pair for 11126.png
# Created pair for 11127.png
# Created pair for 11129.png
# Created pair for 11130.png
# Created pair for 11131.png
# Created pair for 11132.png
# Created pair for 11135.png
# Created pair for 11138.png
# Created pair for 11140.png
# Created pair for 11141.png
# Created pair for 11142.png
# Created pair for 11144.png
# Created pair for 11147.png
# Created pair for 11148.png
# Created pair for 11149.png
# Created pair for 11150.png
# Created pair for 11152.png
# Created pair for 11155.png
# Created pair for 11157.png
# Created pair for 11158.png
# Created pair for 11160.png
# Created pair for 11163.png
# Created pair for 11164.png
# Created pair for 11165.png
# Created pair for 11167.png
# Created pair for 11168.png
# Created pair for 11169.png
# Created pair for 11172.png
# Created pair for 11173.png
# Created pair for 11174.png
# Created pair for 11176.png
# Created pair for 11177.png
# Created pair for 11178.png
# Created pair for 11182.png
# Created pair for 11185.png
# Created pair for 11186.png
# Created pair for 11187.png
# Created pair for 11188.png
# Created pair for 11189.png
# Created pair for 11190.png
# Created pair for 11191.png
# Created pair for 11192.png
# Created pair for 11194.png
# Created pair for 11196.png
# Created pair for 11198.png
# Created pair for 11199.png
# Created pair for 11201.png
# Created pair for 11203.png
# Created pair for 11204.png
# Created pair for 11205.png
# Created pair for 11207.png
# Created pair for 11212.png
# Created pair for 11213.png
# Created pair for 11214.png
# Created pair for 11215.png
# Created pair for 11216.png
# Created pair for 11217.png
# Created pair for 11218.png
# Created pair for 11219.png
# Created pair for 11221.png
# Created pair for 11222.png
# Created pair for 11223.png
# Created pair for 11228.png
# Created pair for 11229.png
# Created pair for 11231.png
# Created pair for 11232.png
# Created pair for 11234.png
# Created pair for 11236.png
# Created pair for 11239.png
# Created pair for 11240.png
# Created pair for 11241.png
# Created pair for 11242.png
# Created pair for 11244.png
# Created pair for 11245.png
# Created pair for 11246.png
# Created pair for 11247.png
# Created pair for 11251.png
# Created pair for 11252.png
# Created pair for 11253.png
# Created pair for 11255.png
# Created pair for 11256.png
# Created pair for 11258.png
# Created pair for 11259.png
# Created pair for 11261.png
# Created pair for 11264.png
# Created pair for 11265.png
# Created pair for 11269.png
# Created pair for 11270.png
# Created pair for 11273.png
# Created pair for 11274.png
# Created pair for 11276.png
# Created pair for 11277.png
# Created pair for 11278.png
# Created pair for 11280.png
# Created pair for 11281.png
# Created pair for 11283.png
# Created pair for 11286.png
# Created pair for 11287.png
# Created pair for 11288.png
# Created pair for 11289.png
# Created pair for 11290.png
# Created pair for 11291.png
# Created pair for 11292.png
# Created pair for 11293.png
# Created pair for 11295.png
# Created pair for 11297.png
# Created pair for 11298.png
# Created pair for 11302.png
# Created pair for 11304.png
# Created pair for 11305.png
# Created pair for 11307.png
# Created pair for 11309.png
# Created pair for 11310.png
# Created pair for 11311.png
# Created pair for 11313.png
# Created pair for 11317.png
# Created pair for 11322.png
# Created pair for 11324.png
# Created pair for 11325.png
# Created pair for 11330.png
# Created pair for 11332.png
# Created pair for 11334.png
# Created pair for 11338.png
# Created pair for 11339.png
# Created pair for 11341.png
# Created pair for 11342.png
# Created pair for 11343.png
# Created pair for 11344.png
# Created pair for 11346.png
# Created pair for 11347.png
# Created pair for 11348.png
# Created pair for 11349.png
# Created pair for 11354.png
# Created pair for 11356.png
# Created pair for 11357.png
# Created pair for 11358.png
# Created pair for 11360.png
# Created pair for 11361.png
# Created pair for 11362.png
# Created pair for 11365.png
# Created pair for 11366.png
# Created pair for 11367.png
# Created pair for 11368.png
# Created pair for 11369.png
# Created pair for 11370.png
# Created pair for 11372.png
# Created pair for 11373.png
# Created pair for 11374.png
# Created pair for 11376.png
# Created pair for 11378.png
# Created pair for 11379.png
# Created pair for 11382.png
# Created pair for 11383.png
# Created pair for 11384.png
# Created pair for 11385.png
# Created pair for 11387.png
# Created pair for 11388.png
# Created pair for 11389.png
# Created pair for 11391.png
# Created pair for 11392.png
# Created pair for 11395.png
# Created pair for 11396.png
# Created pair for 11397.png
# Created pair for 11398.png
# Created pair for 11401.png
# Created pair for 11402.png
# Created pair for 11404.png
# Created pair for 11405.png
# Created pair for 11406.png
# Created pair for 11407.png
# Created pair for 11408.png
# Created pair for 11409.png
# Created pair for 11410.png
# Created pair for 11411.png
# Created pair for 11413.png
# Created pair for 11414.png
# Created pair for 11416.png
# Created pair for 11418.png
# Created pair for 11419.png
# Created pair for 11421.png
# Created pair for 11422.png
# Created pair for 11423.png
# Created pair for 11426.png
# Created pair for 11428.png
# Created pair for 11429.png
# Created pair for 11431.png
# Created pair for 11434.png
# Created pair for 11435.png
# Created pair for 11436.png
# Created pair for 11437.png
# Created pair for 11438.png
# Created pair for 11439.png
# Created pair for 11440.png
# Created pair for 11441.png
# Created pair for 11442.png
# Created pair for 11444.png
# Created pair for 11445.png
# Created pair for 11446.png
# Created pair for 11447.png
# Created pair for 11448.png
# Created pair for 11449.png
# Created pair for 11451.png
# Created pair for 11452.png
# Created pair for 11453.png
# Created pair for 11454.png
# Created pair for 11455.png
# Created pair for 11456.png
# Created pair for 11458.png
# Created pair for 11459.png
# Created pair for 11460.png
# Created pair for 11461.png
# Created pair for 11463.png
# Created pair for 11464.png
# Created pair for 11467.png
# Created pair for 11468.png
# Created pair for 11469.png
# Created pair for 11470.png
# Created pair for 11472.png
# Created pair for 11473.png
# Created pair for 11474.png
# Created pair for 11475.png
# Created pair for 11476.png
# Created pair for 11477.png
# Created pair for 11481.png
# Created pair for 11484.png
# Created pair for 11486.png
# Created pair for 11487.png
# Created pair for 11488.png
# Created pair for 11489.png
# Created pair for 11493.png
# Created pair for 11494.png
# Created pair for 11495.png
# Created pair for 11496.png
# Created pair for 11497.png
# Created pair for 11499.png
# Created pair for 11500.png
# Created pair for 11502.png
# Created pair for 11503.png
# Created pair for 11505.png
# Created pair for 11507.png
# Created pair for 11508.png
# Created pair for 11509.png
# Created pair for 11512.png
# Created pair for 11514.png
# Created pair for 11515.png
# Created pair for 11519.png
# Created pair for 11524.png
# Created pair for 11525.png
# Created pair for 11526.png
# Created pair for 11527.png
# Created pair for 11528.png
# Created pair for 11529.png
# Created pair for 11531.png
# Created pair for 11532.png
# Created pair for 11533.png
# Created pair for 11537.png
# Created pair for 11538.png
# Created pair for 11539.png
# Created pair for 11540.png
# Created pair for 11541.png
# Created pair for 11542.png
# Created pair for 11543.png
# Created pair for 11544.png
# Created pair for 11546.png
# Created pair for 11549.png
# Created pair for 11550.png
# Created pair for 11553.png
# Created pair for 11555.png
# Created pair for 11557.png
# Created pair for 11558.png
# Created pair for 11559.png
# Created pair for 11566.png
# Created pair for 11568.png
# Created pair for 11572.png
# Created pair for 11575.png
# Created pair for 11576.png
# Created pair for 11577.png
# Created pair for 11578.png
# Created pair for 11581.png
# Created pair for 11582.png
# Created pair for 11583.png
# Created pair for 11584.png
# Created pair for 11585.png
# Created pair for 11586.png
# Created pair for 11588.png
# Created pair for 11589.png
# Created pair for 11590.png
# Created pair for 11591.png
# Created pair for 11594.png
# Created pair for 11595.png
# Created pair for 11596.png
# Created pair for 11599.png
# Created pair for 11602.png
# Created pair for 11603.png
# Created pair for 11604.png
# Created pair for 11605.png
# Created pair for 11606.png
# Created pair for 11607.png
# Created pair for 11608.png
# Created pair for 11609.png
# Created pair for 11610.png
# Created pair for 11611.png
# Created pair for 11613.png
# Created pair for 11616.png
# Created pair for 11618.png
# Created pair for 11620.png
# Created pair for 11621.png
# Created pair for 11623.png
# Created pair for 11625.png
# Created pair for 11627.png
# Created pair for 11628.png
# Created pair for 11630.png
# Created pair for 11631.png
# Created pair for 11632.png
# Created pair for 11633.png
# Created pair for 11634.png
# Created pair for 11641.png
# Created pair for 11643.png
# Created pair for 11644.png
# Created pair for 11645.png
# Created pair for 11646.png
# Created pair for 11647.png
# Created pair for 11648.png
# Created pair for 11652.png
# Created pair for 11654.png
# Created pair for 11656.png
# Created pair for 11658.png
# Created pair for 11660.png
# Created pair for 11661.png
# Created pair for 11664.png
# Created pair for 11665.png
# Created pair for 11666.png
# Created pair for 11667.png
# Created pair for 11668.png
# Created pair for 11670.png
# Created pair for 11672.png
# Created pair for 11673.png
# Created pair for 11675.png
# Created pair for 11676.png
# Created pair for 11678.png
# Created pair for 11679.png
# Created pair for 11681.png
# Created pair for 11682.png
# Created pair for 11684.png
# Created pair for 11688.png
# Created pair for 11690.png
# Created pair for 11691.png
# Created pair for 11692.png
# Created pair for 11694.png
# Created pair for 11696.png
# Created pair for 11697.png
# Created pair for 11699.png
# Created pair for 11700.png
# Created pair for 11702.png
# Created pair for 11703.png
# Created pair for 11705.png
# Created pair for 11706.png
# Created pair for 11707.png
# Created pair for 11708.png
# Created pair for 11709.png
# Created pair for 11710.png
# Created pair for 11711.png
# Created pair for 11712.png
# Created pair for 11713.png
# Created pair for 11714.png
# Created pair for 11717.png
# Created pair for 11719.png
# Created pair for 11722.png
# Created pair for 11724.png
# Created pair for 11725.png
# Created pair for 11727.png
# Created pair for 11731.png
# Created pair for 11736.png
# Created pair for 11737.png
# Created pair for 11738.png
# Created pair for 11739.png
# Created pair for 11740.png
# Created pair for 11741.png
# Created pair for 11742.png
# Created pair for 11744.png
# Created pair for 11745.png
# Created pair for 11746.png
# Created pair for 11747.png
# Created pair for 11748.png
# Created pair for 11750.png
# Created pair for 11751.png
# Created pair for 11752.png
# Created pair for 11753.png
# Created pair for 11755.png
# Created pair for 11757.png
# Created pair for 11758.png
# Created pair for 11759.png
# Created pair for 11760.png
# Created pair for 11762.png
# Created pair for 11763.png
# Created pair for 11764.png
# Created pair for 11765.png
# Created pair for 11769.png
# Created pair for 11770.png
# Created pair for 11771.png
# Created pair for 11775.png
# Created pair for 11777.png
# Created pair for 11778.png
# Created pair for 11779.png
# Created pair for 11782.png
# Created pair for 11783.png
# Created pair for 11784.png
# Created pair for 11785.png
# Created pair for 11786.png
# Created pair for 11787.png
# Created pair for 11788.png
# Created pair for 11791.png
# Created pair for 11792.png
# Created pair for 11793.png
# Created pair for 11795.png
# Created pair for 11796.png
# Created pair for 11801.png
# Created pair for 11802.png
# Created pair for 11804.png
# Created pair for 11806.png
# Created pair for 11807.png
# Created pair for 11808.png
# Created pair for 11809.png
# Created pair for 11811.png
# Created pair for 11815.png
# Created pair for 11816.png
# Created pair for 11819.png
# Created pair for 11820.png
# Created pair for 11822.png
# Created pair for 11823.png
# Created pair for 11824.png
# Created pair for 11825.png
# Created pair for 11826.png
# Created pair for 11827.png
# Created pair for 11828.png
# Created pair for 11831.png
# Created pair for 11833.png
# Created pair for 11835.png
# Created pair for 11836.png
# Created pair for 11837.png
# Created pair for 11838.png
# Created pair for 11839.png
# Created pair for 11841.png
# Created pair for 11842.png
# Created pair for 11843.png
# Created pair for 11844.png
# Created pair for 11846.png
# Created pair for 11847.png
# Created pair for 11848.png
# Created pair for 11849.png
# Created pair for 11850.png
# Created pair for 11851.png
# Created pair for 11852.png
# Created pair for 11853.png
# Created pair for 11854.png
# Created pair for 11855.png
# Created pair for 11856.png
# Created pair for 11857.png
# Created pair for 11859.png
# Created pair for 11861.png
# Created pair for 11863.png
# Created pair for 11865.png
# Created pair for 11867.png
# Created pair for 11869.png
# Created pair for 11870.png
# Created pair for 11872.png
# Created pair for 11873.png
# Created pair for 11874.png
# Created pair for 11875.png
# Created pair for 11876.png
# Created pair for 11877.png
# Created pair for 11878.png
# Created pair for 11880.png
# Created pair for 11881.png
# Created pair for 11882.png
# Created pair for 11883.png
# Created pair for 11884.png
# Created pair for 11885.png
# Created pair for 11886.png
# Created pair for 11887.png
# Created pair for 11888.png
# Created pair for 11889.png
# Created pair for 11890.png
# Created pair for 11891.png
# Created pair for 11892.png
# Created pair for 11893.png
# Created pair for 11894.png
# Created pair for 11895.png
# Created pair for 11897.png
# Created pair for 11898.png
# Created pair for 11899.png
# Created pair for 11901.png
# Created pair for 11902.png
# Created pair for 11903.png
# Created pair for 11904.png
# Created pair for 11907.png
# Created pair for 11908.png
# Created pair for 11909.png
# Created pair for 11910.png
# Created pair for 11912.png
# Created pair for 11913.png
# Created pair for 11914.png
# Created pair for 11915.png
# Created pair for 11916.png
# Created pair for 11917.png
# Created pair for 11918.png
# Created pair for 11920.png
# Created pair for 11921.png
# Created pair for 11922.png
# Created pair for 11923.png
# Created pair for 11924.png
# Created pair for 11926.png
# Created pair for 11927.png
# Created pair for 11928.png
# Created pair for 11929.png
# Created pair for 11931.png
# Created pair for 11932.png
# Created pair for 11934.png
# Created pair for 11935.png
# Created pair for 11937.png
# Created pair for 11938.png
# Created pair for 11939.png
# Created pair for 11940.png
# Created pair for 11943.png
# Created pair for 11944.png
# Created pair for 11945.png
# Created pair for 11947.png
# Created pair for 11948.png
# Created pair for 11949.png
# Created pair for 11950.png
# Created pair for 11951.png
# Created pair for 11953.png
# Created pair for 11954.png
# Created pair for 11957.png
# Created pair for 11958.png
# Created pair for 11959.png
# Created pair for 11960.png
# Created pair for 11961.png
# Created pair for 11962.png
# Created pair for 11967.png
# Created pair for 11968.png
# Created pair for 11969.png
# Created pair for 11970.png
# Created pair for 11972.png
# Created pair for 11976.png
# Created pair for 11977.png
# Created pair for 11978.png
# Created pair for 11979.png
# Created pair for 11980.png
# Created pair for 11982.png
# Created pair for 11983.png
# Created pair for 11984.png
# Created pair for 11985.png
# Created pair for 11986.png
# Created pair for 11988.png
# Created pair for 11989.png
# Created pair for 11991.png
# Created pair for 11993.png
# Created pair for 11995.png
# Created pair for 11996.png
# Created pair for 11997.png
# Created pair for 11999.png
# Created pair for 12000.png
# Created pair for 12003.png
# Created pair for 12004.png
# Created pair for 12005.png
# Created pair for 12007.png
# Created pair for 12008.png
# Created pair for 12010.png
# Created pair for 12011.png
# Created pair for 12012.png
# Created pair for 12013.png
# Created pair for 12014.png
# Created pair for 12015.png
# Created pair for 12017.png
# Created pair for 12020.png
# Created pair for 12022.png
# Created pair for 12023.png
# Created pair for 12024.png
# Created pair for 12026.png
# Created pair for 12027.png
# Created pair for 12028.png
# Created pair for 12030.png
# Created pair for 12031.png
# Created pair for 12034.png
# Created pair for 12036.png
# Created pair for 12039.png
# Created pair for 12040.png
# Created pair for 12041.png
# Created pair for 12042.png
# Created pair for 12043.png
# Created pair for 12044.png
# Created pair for 12045.png
# Created pair for 12047.png
# Created pair for 12049.png
# Created pair for 12050.png
# Created pair for 12051.png
# Created pair for 12052.png
# Created pair for 12053.png
# Created pair for 12054.png
# Created pair for 12055.png
# Created pair for 12056.png
# Created pair for 12057.png
# Created pair for 12058.png
# Created pair for 12060.png
# Created pair for 12061.png
# Created pair for 12065.png
# Created pair for 12066.png
# Created pair for 12068.png
# Created pair for 12069.png
# Created pair for 12071.png
# Created pair for 12072.png
# Created pair for 12073.png
# Created pair for 12074.png
# Created pair for 12077.png
# Created pair for 12078.png
# Created pair for 12082.png
# Created pair for 12085.png
# Created pair for 12086.png
# Created pair for 12088.png
# Created pair for 12089.png
# Created pair for 12091.png
# Created pair for 12093.png
# Created pair for 12094.png
# Created pair for 12096.png
# Created pair for 12097.png
# Created pair for 12098.png
# Created pair for 12099.png
# Created pair for 12100.png
# Created pair for 12101.png
# Created pair for 12103.png
# Created pair for 12104.png
# Created pair for 12106.png
# Created pair for 12108.png
# Created pair for 12109.png
# Created pair for 12110.png
# Created pair for 12113.png
# Created pair for 12114.png
# Created pair for 12115.png
# Created pair for 12116.png
# Created pair for 12117.png
# Created pair for 12120.png
# Created pair for 12121.png
# Created pair for 12122.png
# Created pair for 12123.png
# Created pair for 12124.png
# Created pair for 12126.png
# Created pair for 12128.png
# Created pair for 12129.png
# Created pair for 12130.png
# Created pair for 12131.png
# Created pair for 12132.png
# Created pair for 12133.png
# Created pair for 12138.png
# Created pair for 12139.png
# Created pair for 12140.png
# Created pair for 12142.png
# Created pair for 12143.png
# Created pair for 12144.png
# Created pair for 12145.png
# Created pair for 12147.png
# Created pair for 12148.png
# Created pair for 12150.png
# Created pair for 12151.png
# Created pair for 12153.png
# Created pair for 12154.png
# Created pair for 12155.png
# Created pair for 12157.png
# Created pair for 12158.png
# Created pair for 12160.png
# Created pair for 12162.png
# Created pair for 12163.png
# Created pair for 12164.png
# Created pair for 12166.png
# Created pair for 12167.png
# Created pair for 12170.png
# Created pair for 12171.png
# Created pair for 12174.png
# Created pair for 12176.png
# Created pair for 12177.png
# Created pair for 12178.png
# Created pair for 12180.png
# Created pair for 12181.png
# Created pair for 12182.png
# Created pair for 12183.png
# Created pair for 12184.png
# Created pair for 12185.png
# Created pair for 12186.png
# Created pair for 12188.png
# Created pair for 12190.png
# Created pair for 12192.png
# Created pair for 12194.png
# Created pair for 12195.png
# Created pair for 12196.png
# Created pair for 12197.png
# Created pair for 12198.png
# Created pair for 12200.png
# Created pair for 12201.png
# Created pair for 12202.png
# Created pair for 12203.png
# Created pair for 12204.png
# Created pair for 12205.png
# Created pair for 12207.png
# Created pair for 12208.png
# Created pair for 12209.png
# Created pair for 12210.png
# Created pair for 12211.png
# Created pair for 12212.png
# Created pair for 12213.png
# Created pair for 12215.png
# Created pair for 12216.png
# Created pair for 12218.png
# Created pair for 12219.png
# Created pair for 12220.png
# Created pair for 12221.png
# Created pair for 12222.png
# Created pair for 12223.png
# Created pair for 12224.png
# Created pair for 12225.png
# Created pair for 12226.png
# Created pair for 12227.png
# Created pair for 12228.png
# Created pair for 12230.png
# Created pair for 12232.png
# Created pair for 12233.png
# Created pair for 12234.png
# Created pair for 12235.png
# Created pair for 12236.png
# Created pair for 12237.png
# Created pair for 12238.png
# Created pair for 12239.png
# Created pair for 12244.png
# Created pair for 12245.png
# Created pair for 12246.png
# Created pair for 12247.png
# Created pair for 12248.png
# Created pair for 12249.png
# Created pair for 12250.png
# Created pair for 12251.png
# Created pair for 12252.png
# Created pair for 12253.png
# Created pair for 12255.png
# Created pair for 12256.png
# Created pair for 12257.png
# Created pair for 12258.png
# Created pair for 12259.png
# Created pair for 12260.png
# Created pair for 12261.png
# Created pair for 12263.png
# Created pair for 12265.png
# Created pair for 12267.png
# Created pair for 12268.png
# Created pair for 12269.png
# Created pair for 12272.png
# Created pair for 12273.png
# Created pair for 12277.png
# Created pair for 12279.png
# Created pair for 12280.png
# Created pair for 12282.png
# Created pair for 12285.png
# Created pair for 12286.png
# Created pair for 12288.png
# Created pair for 12290.png
# Created pair for 12293.png
# Created pair for 12294.png
# Created pair for 12295.png
# Created pair for 12296.png
# Created pair for 12302.png
# Created pair for 12304.png
# Created pair for 12305.png
# Created pair for 12308.png
# Created pair for 12310.png
# Created pair for 12311.png
# Created pair for 12313.png
# Created pair for 12316.png
# Created pair for 12317.png
# Created pair for 12319.png
# Created pair for 12320.png
# Created pair for 12321.png
# Created pair for 12322.png
# Created pair for 12323.png
# Created pair for 12326.png
# Created pair for 12327.png
# Created pair for 12328.png
# Created pair for 12330.png
# Created pair for 12331.png
# Created pair for 12332.png
# Created pair for 12334.png
# Created pair for 12335.png
# Created pair for 12336.png
# Created pair for 12337.png
# Created pair for 12338.png
# Created pair for 12340.png
# Created pair for 12342.png
# Created pair for 12345.png
# Created pair for 12349.png
# Created pair for 12352.png
# Created pair for 12353.png
# Created pair for 12354.png
# Created pair for 12355.png
# Created pair for 12357.png
# Created pair for 12359.png
# Created pair for 12360.png
# Created pair for 12362.png
# Created pair for 12366.png
# Created pair for 12367.png
# Created pair for 12368.png
# Created pair for 12369.png
# Created pair for 12372.png
# Created pair for 12373.png
# Created pair for 12376.png
# Created pair for 12377.png
# Created pair for 12378.png
# Created pair for 12379.png
# Created pair for 12382.png
# Created pair for 12385.png
# Created pair for 12387.png
# Created pair for 12389.png
# Created pair for 12391.png
# Created pair for 12392.png
# Created pair for 12394.png
# Created pair for 12396.png
# Created pair for 12397.png
# Created pair for 12398.png
# Created pair for 12399.png
# Created pair for 12400.png
# Created pair for 12401.png
# Created pair for 12402.png
# Created pair for 12403.png
# Created pair for 12406.png
# Created pair for 12407.png
# Created pair for 12408.png
# Created pair for 12410.png
# Created pair for 12411.png
# Created pair for 12415.png
# Created pair for 12416.png
# Created pair for 12417.png
# Created pair for 12418.png
# Created pair for 12419.png
# Created pair for 12421.png
# Created pair for 12424.png
# Created pair for 12425.png
# Created pair for 12426.png
# Created pair for 12427.png
# Created pair for 12429.png
# Created pair for 12430.png
# Created pair for 12431.png
# Created pair for 12432.png
# Created pair for 12435.png
# Created pair for 12436.png
# Created pair for 12437.png
# Created pair for 12438.png
# Created pair for 12439.png
# Created pair for 12441.png
# Created pair for 12442.png
# Created pair for 12445.png
# Created pair for 12447.png
# Created pair for 12448.png
# Created pair for 12449.png
# Created pair for 12450.png
# Created pair for 12451.png
# Created pair for 12452.png
# Created pair for 12456.png
# Created pair for 12457.png
# Created pair for 12458.png
# Created pair for 12460.png
# Created pair for 12461.png
# Created pair for 12462.png
# Created pair for 12464.png
# Created pair for 12466.png
# Created pair for 12468.png
# Created pair for 12469.png
# Created pair for 12475.png
# Created pair for 12476.png
# Created pair for 12478.png
# Created pair for 12479.png
# Created pair for 12480.png
# Created pair for 12481.png
# Created pair for 12482.png
# Created pair for 12483.png
# Created pair for 12484.png
# Created pair for 12485.png
# Created pair for 12489.png
# Created pair for 12491.png
# Created pair for 12493.png
# Created pair for 12494.png
# Created pair for 12495.png
# Created pair for 12496.png
# Created pair for 12502.png
# Created pair for 12504.png
# Created pair for 12505.png
# Created pair for 12506.png
# Created pair for 12507.png
# Created pair for 12509.png
# Created pair for 12511.png
# Created pair for 12513.png
# Created pair for 12514.png
# Created pair for 12515.png
# Created pair for 12516.png
# Created pair for 12517.png
# Created pair for 12520.png
# Created pair for 12522.png
# Created pair for 12524.png
# Created pair for 12528.png
# Created pair for 12530.png
# Created pair for 12531.png
# Created pair for 12532.png
# Created pair for 12533.png
# Created pair for 12534.png
# Created pair for 12535.png
# Created pair for 12536.png
# Created pair for 12538.png
# Created pair for 12540.png
# Created pair for 12543.png
# Created pair for 12545.png
# Created pair for 12546.png
# Created pair for 12549.png
# Created pair for 12550.png
# Created pair for 12551.png
# Created pair for 12553.png
# Created pair for 12555.png
# Created pair for 12557.png
# Created pair for 12558.png
# Created pair for 12559.png
# Created pair for 12560.png
# Created pair for 12562.png
# Created pair for 12564.png
# Created pair for 12565.png
# Created pair for 12566.png
# Created pair for 12568.png
# Created pair for 12569.png
# Created pair for 12570.png
# Created pair for 12571.png
# Created pair for 12573.png
# Created pair for 12574.png
# Created pair for 12575.png
# Created pair for 12577.png
# Created pair for 12578.png
# Created pair for 12579.png
# Created pair for 12580.png
# Created pair for 12586.png
# Created pair for 12588.png
# Created pair for 12590.png
# Created pair for 12591.png
# Created pair for 12592.png
# Created pair for 12594.png
# Created pair for 12595.png
# Created pair for 12596.png
# Created pair for 12597.png
# Created pair for 12598.png
# Created pair for 12599.png
# Created pair for 12601.png
# Created pair for 12602.png
# Created pair for 12605.png
# Created pair for 12607.png
# Created pair for 12610.png
# Created pair for 12611.png
# Created pair for 12612.png
# Created pair for 12613.png
# Created pair for 12615.png
# Created pair for 12620.png
# Created pair for 12622.png
# Created pair for 12623.png
# Created pair for 12625.png
# Created pair for 12626.png
# Created pair for 12629.png
# Created pair for 12631.png
# Created pair for 12633.png
# Created pair for 12635.png
# Created pair for 12636.png
# Created pair for 12637.png
# Created pair for 12638.png
# Created pair for 12640.png
# Created pair for 12643.png
# Created pair for 12644.png
# Created pair for 12646.png
# Created pair for 12648.png
# Created pair for 12649.png
# Created pair for 12652.png
# Created pair for 12653.png
# Created pair for 12655.png
# Created pair for 12657.png
# Created pair for 12661.png
# Created pair for 12662.png
# Created pair for 12663.png
# Created pair for 12664.png
# Created pair for 12665.png
# Created pair for 12667.png
# Created pair for 12668.png
# Created pair for 12669.png
# Created pair for 12670.png
# Created pair for 12671.png
# Created pair for 12672.png
# Created pair for 12673.png
# Created pair for 12674.png
# Created pair for 12675.png
# Created pair for 12676.png
# Created pair for 12678.png
# Created pair for 12680.png
# Created pair for 12681.png
# Created pair for 12682.png
# Created pair for 12685.png
# Created pair for 12686.png
# Created pair for 12687.png
# Created pair for 12690.png
# Created pair for 12691.png
# Created pair for 12692.png
# Created pair for 12693.png
# Created pair for 12700.png
# Created pair for 12702.png
# Created pair for 12704.png
# Created pair for 12705.png
# Created pair for 12706.png
# Created pair for 12707.png
# Created pair for 12708.png
# Created pair for 12709.png
# Created pair for 12710.png
# Created pair for 12713.png
# Created pair for 12715.png
# Created pair for 12718.png
# Created pair for 12724.png
# Created pair for 12725.png
# Created pair for 12726.png
# Created pair for 12727.png
# Created pair for 12730.png
# Created pair for 12731.png
# Created pair for 12732.png
# Created pair for 12733.png
# Created pair for 12734.png
# Created pair for 12735.png
# Created pair for 12736.png
# Created pair for 12738.png
# Created pair for 12739.png
# Created pair for 12740.png
# Created pair for 12744.png
# Created pair for 12745.png
# Created pair for 12746.png
# Created pair for 12747.png
# Created pair for 12748.png
# Created pair for 12749.png
# Created pair for 12750.png
# Created pair for 12752.png
# Created pair for 12753.png
# Created pair for 12754.png
# Created pair for 12756.png
# Created pair for 12760.png
# Created pair for 12762.png
# Created pair for 12764.png
# Created pair for 12765.png
# Created pair for 12766.png
# Created pair for 12767.png
# Created pair for 12771.png
# Created pair for 12772.png
# Created pair for 12774.png
# Created pair for 12775.png
# Created pair for 12776.png
# Created pair for 12778.png
# Created pair for 12779.png
# Created pair for 12780.png
# Created pair for 12782.png
# Created pair for 12783.png
# Created pair for 12784.png
# Created pair for 12786.png
# Created pair for 12787.png
# Created pair for 12789.png
# Created pair for 12790.png
# Created pair for 12793.png
# Created pair for 12797.png
# Created pair for 12798.png
# ...
# Created pair for 16088.png
# Created pair for 16089.png
# Created pair for 16090.png
# Created pair for 16091.png
# Created pair for 16093.png
# Created pair for 16095.png
# Created pair for 16098.png
# Created pair for 16099.png
# Created pair for 16102.png
# Created pair for 16103.png
# Created pair for 16106.png
# Created pair for 16108.png
# Created pair for 16111.png
# Created pair for 16112.png
# Created pair for 16118.png
# Created pair for 16119.png
# Created pair for 16120.png
# Created pair for 16122.png
# Created pair for 16123.png
# Created pair for 16125.png
# Created pair for 16127.png
# Created pair for 16128.png
# Created pair for 16129.png
# Created pair for 16130.png
# Created pair for 16132.png
# Created pair for 16134.png
# Created pair for 16135.png
# Created pair for 16136.png
# Created pair for 16138.png
# Created pair for 16141.png
# Created pair for 16144.png
# Created pair for 16145.png
# Created pair for 16147.png
# Created pair for 16148.png
# Created pair for 16149.png
# Created pair for 16152.png
# Created pair for 16153.png
# Created pair for 16154.png
# Created pair for 16155.png
# Created pair for 16156.png
# Created pair for 16157.png
# Created pair for 16159.png
# Created pair for 16161.png
# Created pair for 16162.png
# Created pair for 16163.png
# Created pair for 16165.png
# Created pair for 16170.png
# Created pair for 16171.png
# Created pair for 16172.png
# Created pair for 16175.png
# Created pair for 16176.png
# Created pair for 16177.png
# Created pair for 16178.png
# Created pair for 16180.png
# Created pair for 16183.png
# Created pair for 16185.png
# Created pair for 16186.png
# Created pair for 16189.png
# Created pair for 16192.png
# Created pair for 16194.png
# Created pair for 16195.png
# Created pair for 16196.png
# Created pair for 16197.png
# Created pair for 16198.png
# Created pair for 16200.png
# Created pair for 16201.png
# Created pair for 16202.png
# Created pair for 16204.png
# Created pair for 16205.png
# Created pair for 16206.png
# Created pair for 16207.png
# Created pair for 16208.png
# Created pair for 16209.png
# Created pair for 16210.png
# Created pair for 16212.png
# Created pair for 16213.png
# Created pair for 16216.png
# Created pair for 16217.png
# Created pair for 16220.png
# Created pair for 16221.png
# Created pair for 16222.png
# Created pair for 16223.png
# Created pair for 16224.png
# Created pair for 16225.png
# Created pair for 16228.png
# Created pair for 16229.png
# Created pair for 16231.png
# Created pair for 16233.png
# Created pair for 16235.png
# Created pair for 16236.png
# Created pair for 16244.png
# Created pair for 16245.png
# Created pair for 16246.png
# Created pair for 16247.png
# Created pair for 16248.png
# Created pair for 16249.png
# Created pair for 16250.png
# Created pair for 16251.png
# Created pair for 16252.png
# Created pair for 16253.png
# Created pair for 16254.png
# Created pair for 16255.png
# Created pair for 16256.png
# Created pair for 16259.png
# Created pair for 16260.png
# Created pair for 16262.png
# Created pair for 16265.png
# Created pair for 16266.png
# Created pair for 16267.png
# Created pair for 16268.png
# Created pair for 16269.png
# Created pair for 16270.png
# Created pair for 16271.png
# Created pair for 16273.png
# Created pair for 16274.png
# Created pair for 16275.png
# Created pair for 16276.png
# Created pair for 16277.png
# Created pair for 16281.png
# Created pair for 16282.png
# Created pair for 16283.png
# Created pair for 16285.png
# Created pair for 16286.png
# Created pair for 16289.png
# Created pair for 16291.png
# Created pair for 16293.png
# Created pair for 16294.png
# Created pair for 16296.png
# Created pair for 16297.png
# Created pair for 16298.png
# Created pair for 16299.png
# Created pair for 16300.png
# Created pair for 16302.png
# Created pair for 16303.png
# Created pair for 16306.png
# Created pair for 16307.png
# Created pair for 16308.png
# Created pair for 16310.png
# Created pair for 16311.png
# Created pair for 16312.png
# Created pair for 16313.png
# Created pair for 16314.png
# Created pair for 16315.png
# Created pair for 16316.png
# Created pair for 16318.png
# Created pair for 16320.png
# Created pair for 16321.png
# Created pair for 16325.png
# Created pair for 16328.png
# Created pair for 16331.png
# Created pair for 16334.png
# Created pair for 16336.png
# Created pair for 16337.png
# Created pair for 16339.png
# Created pair for 16343.png
# Created pair for 16344.png
# Created pair for 16347.png
# Created pair for 16348.png
# Created pair for 16350.png
# Created pair for 16351.png
# Created pair for 16353.png
# Created pair for 16354.png
# Created pair for 16356.png
# Created pair for 16357.png
# Created pair for 16359.png
# Created pair for 16361.png
# Created pair for 16365.png
# Created pair for 16366.png
# Created pair for 16369.png
# Created pair for 16370.png
# Created pair for 16373.png
# Created pair for 16374.png
# Created pair for 16375.png
# Created pair for 16376.png
# Created pair for 16379.png
# Created pair for 16380.png
# Created pair for 16381.png
# Created pair for 16382.png
# Created pair for 16383.png
# Created pair for 16385.png
# Created pair for 16386.png
# Created pair for 16388.png
# Created pair for 16390.png
# Created pair for 16392.png
# Created pair for 16393.png
# Created pair for 16396.png
# Created pair for 16397.png
# Created pair for 16399.png
# Created pair for 16401.png
# Created pair for 16402.png
# Created pair for 16403.png
# Created pair for 16404.png
# Created pair for 16405.png
# Created pair for 16406.png
# Created pair for 16407.png
# Created pair for 16410.png
# Created pair for 16412.png
# Created pair for 16413.png
# Created pair for 16414.png
# Created pair for 16415.png
# Created pair for 16416.png
# Created pair for 16417.png
# Created pair for 16419.png
# Created pair for 16421.png
# Created pair for 16422.png
# Created pair for 16423.png
# Created pair for 16424.png
# Created pair for 16425.png
# Created pair for 16429.png
# Created pair for 16430.png
# Created pair for 16431.png
# Created pair for 16434.png
# Created pair for 16435.png
# Created pair for 16439.png
# Created pair for 16440.png
# Created pair for 16442.png
# Created pair for 16443.png
# Created pair for 16444.png
# Created pair for 16447.png
# Created pair for 16448.png
# Created pair for 16451.png
# Created pair for 16454.png
# Created pair for 16455.png
# Created pair for 16456.png
# Created pair for 16458.png
# Created pair for 16460.png
# Created pair for 16461.png
# Created pair for 16462.png
# Created pair for 16464.png
# Created pair for 16466.png
# Created pair for 16468.png
# Created pair for 16470.png
# Created pair for 16472.png
# Created pair for 16475.png
# Created pair for 16476.png
# Created pair for 16477.png
# Created pair for 16480.png
# Created pair for 16482.png
# Created pair for 16483.png
# Created pair for 16485.png
# Created pair for 16486.png
# Created pair for 16487.png
# Created pair for 16488.png
# Created pair for 16489.png
# Created pair for 16490.png
# Created pair for 16492.png
# Created pair for 16497.png
# Created pair for 16498.png
# Created pair for 16500.png
# Created pair for 16502.png
# Created pair for 16503.png
# Created pair for 16504.png
# Created pair for 16506.png
# Created pair for 16507.png
# Created pair for 16508.png
# Created pair for 16509.png
# Created pair for 16510.png
# Created pair for 16512.png
# Created pair for 16513.png
# Created pair for 16515.png
# Created pair for 16516.png
# Created pair for 16517.png
# Created pair for 16518.png
# Created pair for 16519.png
# Created pair for 16521.png
# Created pair for 16523.png
# Created pair for 16525.png
# Created pair for 16526.png
# Created pair for 16528.png
# Created pair for 16529.png
# Created pair for 16531.png
# Created pair for 16532.png
# Created pair for 16533.png
# Created pair for 16534.png
# Created pair for 16535.png
# Created pair for 16537.png
# Created pair for 16542.png
# Created pair for 16543.png
# Created pair for 16545.png
# Created pair for 16546.png
# Created pair for 16547.png
# Created pair for 16548.png
# Created pair for 16551.png
# Created pair for 16552.png
# Created pair for 16553.png
# Created pair for 16554.png
# Created pair for 16555.png
# Created pair for 16557.png
# Created pair for 16559.png
# Created pair for 16560.png
# Created pair for 16562.png
# Created pair for 16563.png
# Created pair for 16565.png
# Created pair for 16566.png
# Created pair for 16568.png
# Created pair for 16570.png
# Created pair for 16571.png
# Created pair for 16574.png
# Created pair for 16575.png
# Created pair for 16576.png
# Created pair for 16578.png
# Created pair for 16579.png
# Created pair for 16580.png
# Created pair for 16581.png
# Created pair for 16583.png
# Created pair for 16584.png
# Created pair for 16588.png
# Created pair for 16590.png
# Created pair for 16591.png
# Created pair for 16593.png
# Created pair for 16594.png
# Created pair for 16596.png
# Created pair for 16598.png
# Created pair for 16600.png
# Created pair for 16601.png
# Created pair for 16602.png
# Created pair for 16603.png
# Created pair for 16604.png
# Created pair for 16605.png
# Created pair for 16606.png
# Created pair for 16608.png
# Created pair for 16609.png
# Created pair for 16610.png
# Created pair for 16611.png
# Created pair for 16612.png
# Created pair for 16615.png
# Created pair for 16616.png
# Created pair for 16617.png
# Created pair for 16618.png
# Created pair for 16619.png
# Created pair for 16620.png
# Created pair for 16621.png
# Created pair for 16623.png
# Created pair for 16624.png
# Created pair for 16625.png
# Created pair for 16626.png
# Created pair for 16627.png
# Created pair for 16628.png
# Created pair for 16632.png
# Created pair for 16633.png
# Created pair for 16634.png
# Created pair for 16636.png
# Created pair for 16637.png
# Created pair for 16638.png
# Created pair for 16639.png
# Created pair for 16640.png
# Created pair for 16641.png
# Created pair for 16642.png
# Created pair for 16646.png
# Created pair for 16647.png
# Created pair for 16648.png
# Created pair for 16649.png
# Created pair for 16650.png
# Created pair for 16651.png
# Created pair for 16654.png
# Created pair for 16656.png
# Created pair for 16657.png
# Created pair for 16658.png
# Created pair for 16659.png
# Created pair for 16660.png
# Created pair for 16661.png
# Created pair for 16664.png
# Created pair for 16665.png
# Created pair for 16669.png
# Created pair for 16670.png
# Created pair for 16671.png
# Created pair for 16675.png
# Created pair for 16678.png
# Created pair for 16682.png
# Created pair for 16685.png
# Created pair for 16686.png
# Created pair for 16687.png
# Created pair for 16688.png
# Created pair for 16689.png
# Created pair for 16690.png
# Created pair for 16691.png
# Created pair for 16692.png
# Created pair for 16693.png
# Created pair for 16694.png
# Created pair for 16696.png
# Created pair for 16699.png
# Created pair for 16700.png
# Created pair for 16704.png
# Created pair for 16705.png
# Created pair for 16706.png
# Created pair for 16707.png
# Created pair for 16708.png
# Created pair for 16709.png
# Created pair for 16710.png
# Created pair for 16711.png
# Created pair for 16712.png
# Created pair for 16713.png
# Created pair for 16717.png
# Created pair for 16718.png
# Created pair for 16719.png
# Created pair for 16720.png
# Created pair for 16721.png
# Created pair for 16723.png
# Created pair for 16724.png
# Created pair for 16725.png
# Created pair for 16726.png
# Created pair for 16727.png
# Created pair for 16729.png
# Created pair for 16731.png
# Created pair for 16733.png
# Created pair for 16734.png
# Created pair for 16735.png
# Created pair for 16736.png
# Created pair for 16738.png
# Created pair for 16739.png
# Created pair for 16741.png
# Created pair for 16742.png
# Created pair for 16743.png
# Created pair for 16745.png
# Created pair for 16750.png
# Created pair for 16751.png
# Created pair for 16754.png
# Created pair for 16755.png
# Created pair for 16757.png
# Created pair for 16759.png
# Created pair for 16761.png
# Created pair for 16762.png
# Created pair for 16763.png
# Created pair for 16764.png
# Created pair for 16765.png
# Created pair for 16766.png
# Created pair for 16767.png
# Created pair for 16768.png
# Created pair for 16770.png
# Created pair for 16771.png
# Created pair for 16773.png
# Created pair for 16774.png
# Created pair for 16775.png
# Created pair for 16776.png
# Created pair for 16777.png
# Created pair for 16778.png
# Created pair for 16779.png
# Created pair for 16782.png
# Created pair for 16783.png
# Created pair for 16785.png
# Created pair for 16786.png
# Created pair for 16787.png
# Created pair for 16788.png
# Created pair for 16789.png
# Created pair for 16791.png
# Created pair for 16792.png
# Created pair for 16793.png
# Created pair for 16794.png
# Created pair for 16795.png
# Created pair for 16796.png
# Created pair for 16800.png
# Created pair for 16801.png
# Created pair for 16802.png
# Created pair for 16803.png
# Created pair for 16804.png
# Created pair for 16805.png
# Created pair for 16808.png
# Created pair for 16809.png
# Created pair for 16810.png
# Created pair for 16812.png
# Created pair for 16813.png
# Created pair for 16814.png
# Created pair for 16816.png
# Created pair for 16822.png
# Created pair for 16823.png
# Created pair for 16826.png
# Created pair for 16827.png
# Created pair for 16828.png
# Created pair for 16831.png
# Created pair for 16832.png
# Created pair for 16833.png
# Created pair for 16835.png
# Created pair for 16836.png
# Created pair for 16838.png
# Created pair for 16840.png
# Created pair for 16842.png
# Created pair for 16843.png
# Created pair for 16845.png
# Created pair for 16848.png
# Created pair for 16849.png
# Created pair for 16851.png
# Created pair for 16852.png
# Created pair for 16853.png
# Created pair for 16854.png
# Created pair for 16855.png
# Created pair for 16857.png
# Created pair for 16858.png
# Created pair for 16863.png
# Created pair for 16865.png
# Created pair for 16869.png
# Created pair for 16871.png
# Created pair for 16874.png
# Created pair for 16875.png
# Created pair for 16877.png
# Created pair for 16879.png
# Created pair for 16880.png
# Created pair for 16882.png
# Created pair for 16885.png
# Created pair for 16887.png
# Created pair for 16890.png
# Created pair for 16891.png
# Created pair for 16894.png
# Created pair for 16895.png
# Created pair for 16896.png
# Created pair for 16897.png
# Created pair for 16898.png
# Created pair for 16899.png
# Created pair for 16900.png
# Created pair for 16901.png
# Created pair for 16903.png
# Created pair for 16904.png
# Created pair for 16905.png
# Created pair for 16906.png
# Created pair for 16907.png
# Created pair for 16908.png
# Created pair for 16909.png
# Created pair for 16911.png
# Created pair for 16912.png
# Created pair for 16914.png
# Created pair for 16915.png
# Created pair for 16919.png
# Created pair for 16922.png
# Created pair for 16925.png
# Created pair for 16926.png
# Created pair for 16927.png
# Created pair for 16929.png
# Created pair for 16930.png
# Created pair for 16932.png
# Created pair for 16933.png
# Created pair for 16934.png
# Created pair for 16935.png
# Created pair for 16936.png
# Created pair for 16937.png
# Created pair for 16938.png
# Created pair for 16941.png
# Created pair for 16944.png
# Created pair for 16945.png
# Created pair for 16946.png
# Created pair for 16947.png
# Created pair for 16948.png
# Created pair for 16949.png
# Created pair for 16956.png
# Created pair for 16957.png
# Created pair for 16958.png
# Created pair for 16959.png
# Created pair for 16960.png
# Created pair for 16963.png
# Created pair for 16964.png
# Created pair for 16965.png
# Created pair for 16967.png
# Created pair for 16970.png
# Created pair for 16971.png
# Created pair for 16974.png
# Created pair for 16975.png
# Created pair for 16977.png
# Created pair for 16979.png
# Created pair for 16982.png
# Created pair for 16983.png
# Created pair for 16984.png
# Created pair for 16985.png
# Created pair for 16986.png
# Created pair for 16987.png
# Created pair for 16988.png
# Created pair for 16989.png
# Created pair for 16990.png
# Created pair for 16991.png
# Created pair for 16992.png
# Created pair for 16993.png
# Created pair for 16994.png
# Created pair for 16995.png
# Created pair for 16997.png
# Created pair for 16998.png
# Created pair for 17001.png
# Created pair for 17003.png
# Created pair for 17004.png
# Created pair for 17005.png
# Created pair for 17006.png
# Created pair for 17007.png
# Created pair for 17008.png
# Created pair for 17010.png
# Created pair for 17012.png
# Created pair for 17013.png
# Created pair for 17018.png
# Created pair for 17020.png
# Created pair for 17021.png
# Created pair for 17022.png
# Created pair for 17024.png
# Created pair for 17026.png
# Created pair for 17029.png
# Created pair for 17030.png
# Created pair for 17031.png
# Created pair for 17033.png

# %%
# Cell 1: Imports for Model Building
# !pip install torch torchvision torchaudio
import torch  # For tensor operations and neural networks. What: Core PyTorch library. Why: Builds and trains models. Better: GPU acceleration; flexible over TF for research prototypes.
import torch.nn as nn  # For network modules (Conv2d, etc.). What: NN building blocks. Why: Defines layers. Better: Modular; easy to customize architectures like LapSRN/DRRN.
import torch.nn.functional as F  # For functional ops (ReLU). What: Activation/ops without state. Why: Used in forward passes. Better: Stateless; memory-efficient in recursives.
# Out:
# Requirement already satisfied: torch in e:\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: torchvision in e:\anaconda3\lib\site-packages (0.24.1)
# Requirement already satisfied: torchaudio in e:\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: filelock in e:\anaconda3\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in e:\anaconda3\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in e:\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in e:\anaconda3\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in e:\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in e:\anaconda3\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: setuptools in e:\anaconda3\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: numpy in e:\anaconda3\lib\site-packages (from torchvision) (2.3.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in e:\anaconda3\lib\site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)

# %%
# Cell 3: DRRN Model Definition
class DRRN(nn.Module):
    # What: Deep Recursive Residual Network class.
    # Why: For post-upsampling refinement with deep, efficient structure.
    # How better: Recursive units with sharing (low params ~297K for 52 layers) vs. non-recursive deep nets (e.g., VDSR with more params); multi-path (2^U) captures complex textures better than single-path.
    
    def __init__(self, num_blocks=1, num_units=25, num_filters=128):
        # What: Constructor for B1U25 config.
        # Why: Sets up recursive structure with global/local residuals.
        # How better: Num_units=25 gives depth without explosion; better than shallower (e.g., SRCNN) for fine details in CT refinement.
        super().__init__()  # What: Parent init.
        # Why: Required for Module.
        # How better: Inherits PyTorch utils; standard.
        self.initial_conv = nn.Conv2d(1, num_filters, kernel_size=3, padding=1)  # What: Input to feature space.
        # Why: Expands channels for processing.
        # How better: 128 filters balance capacity/efficiency; better than 64 (more expressive for refinement).
        self.recursive_unit = nn.Sequential(  # What: Shared unit module.
            # Why: Reused in loop for weight sharing.
            # How better: Sharing keeps params low (~297K total); better than unshared (overparametrized, harder to train).
            nn.ReLU(),  # What: Pre-activation ReLU.
            # Why: Non-linearity before conv.
            # How better: Pre-act stabilizes gradients in deep recursives; better than post-act (smoother optimization).
            nn.Conv2d(num_filters, num_filters, kernel_size=3, padding=1, bias=False),  # What: First conv in unit.
            # Why: Feature transform without bias (common in residuals).
            # How better: No bias reduces params slightly; padding keeps size, better than strided.
            nn.ReLU(),  # What: Mid-unit activation.
            # Why: Between convs for complexity.
            # How better: Allows non-linear combos; ReLU fast/simple over Leaky (per paper).
            nn.Conv2d(num_filters, num_filters, kernel_size=3, padding=1, bias=False)  # What: Second conv.
            # Why: Pair completes unit.
            # How better: Two convs per unit > one (depth); no bias for residual norm.
        )
        self.final_conv = nn.Conv2d(num_filters, 1, kernel_size=3, padding=1)  # What: Compresses to residual output.
        # Why: Predicts refinement map.
        # How better: 3x3 local; reduces channels efficiently.
        self.num_units = num_units  # What: Stores loop count.
        # Why: For forward iteration.
        # How better: Configurable; easy scaling vs. hardcoded.
    
    def forward(self, x):
        # What: Forward with recursive local/global residuals.
        # Why: Refines input via multi-path learning.
        # How better: 2^25 paths capture diverse features with few params; better than non-residual (vanishing gradients in 52 layers).
        features = self.initial_conv(x)  # What: Base features.
        # Why: Prepares for recursion.
        # How better: Channel expansion; better start than raw input.
        for _ in range(self.num_units):  # What: Loops units (25x).
            # Why: Builds effective depth (52 layers).
            # How better: Loop with sharing > explicit layers (code/param efficient).
            res = self.recursive_unit(features)  # What: Computes unit output.
            # Why: Local residual block.
            # How better: Pre-act structure > standard ResNet (better for very deep).
            features = features + res  # What: Local add.
            # Why: Skip connection per unit.
            # How better: Accumulates refinements; stabilizes gradients.
        res = self.final_conv(features)  # What: Final residual predict.
        # Why: Maps back to 1ch.
        # How better: Post-recursion; leverages all depth.
        return x + res  # What: Global residual add.
        # Why: Output = input + learned residual.
        # How better: Preserves high-freq from input; better for SR (avoids over-smoothing).

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import os
from PIL import Image  # For loading images; replace if using other formats

# Assume LapSRN class from Cell 1, but with fix to global_up padding
class LapSRN(nn.Module):
    # What: Defines the Laplacian Pyramid Super-Resolution Network class, inheriting from nn.Module.
    # Why: To create a model for progressive image upsampling using a pyramid structure.
    # How better: Unlike single-stage SR models (e.g., SRCNN), LapSRN's pyramid allows multi-scale predictions in one pass, reducing artifacts and improving efficiency by building incrementally; better than GANs for stability without adversarial training.
    def __init__(self, scale_factor=4, num_recursive_blocks=5, num_layers_per_block=5):
        # What: Constructor to initialize model parameters and layers.
        # Why: Sets up configurable hyperparameters like scale and block depths for flexibility.
        # How better: Parameterized init allows easy tuning (e.g., D5R5 config); better than fixed architectures as it adapts to different scales without redesign.
        super().__init__() # What: Calls parent class constructor.
        # Why: Required for nn.Module subclasses to initialize properly.
        # How better: Ensures inheritance of PyTorch functionalities like .to(device); standard and error-free over manual init.
        self.scale_factor = scale_factor # What: Stores the total upsampling factor (e.g., 4 for 4x SR).
        # Why: To determine number of pyramid levels.
        # How better: Explicit storage allows dynamic computation; better than hardcoding for multi-scale support.
        self.pyramid_levels = int(np.log2(scale_factor)) # What: Calculates pyramid levels using log base 2 (e.g., 2 for 4x).
        # Why: Each level doubles resolution progressively.
        # How better: Math-based derivation ensures correctness for power-of-2 scales; more efficient than arbitrary levels, reducing computation vs. non-pyramid nets.
        self.initial_conv = nn.Conv2d(1, 64, kernel_size=3, padding=1) # What: Initial convolutional layer from 1 channel (grayscale CT) to 64 features.
        # Why: Extracts base features from input.
        # How better: 3x3 kernel is local/efficient; padding='same' preserves spatial dims, better than larger kernels (less params) or no padding (size loss).
       
        # What: Creates a list of recursive blocks using ModuleList.
        # Why: For feature embedding with multiple blocks of conv layers.
        # How better: ModuleList allows PyTorch to track params; loops create independent layers, preventing unintended weight sharing issues in comprehensions; better than flat stack (modular for debugging).
        self.recursive_blocks = nn.ModuleList()
        for _ in range(num_recursive_blocks): # What: Outer loop for num_recursive_blocks (5).
            # Why: Builds each block separately.
            # How better: Ensures fresh instances per block; better than list comp with * (avoids syntax errors and sharing).
            layers = [] # What: Temp list for layers in one block.
            # Why: To build sequential per block.
            # How better: Accumulates layers dynamically; flexible for varying depths.
            for _ in range(num_layers_per_block): # What: Inner loop for num_layers_per_block (5).
                # Why: Adds conv + activation pairs per block.
                # How better: Repeated convs build depth efficiently; better than shallow nets (captures complex features with fewer params via recursion).
                layers.append(nn.Conv2d(64, 64, kernel_size=3, padding=1)) # What: Adds 3x3 conv layer.
                # Why: Feature transformation.
                # How better: Consistent 64 channels keep dims; padding maintains size, better than strided (no downsampling needed here).
                layers.append(nn.LeakyReLU(0.2)) # What: Adds LeakyReLU activation.
                # Why: Introduces non-linearity.
                # How better: alpha=0.2 allows small negatives, mitigating dying ReLU; better than ReLU (avoids zero gradients) or sigmoid (no vanishing).
            self.recursive_blocks.append(nn.Sequential(*layers)) # What: Appends Sequential of layers to list.
            # Why: Groups block for easy forward call.
            # How better: Sequential simplifies forward; * unpacks list, clean syntax over manual add_module.
       
        self.up_feature = nn.ConvTranspose2d(64, 64, kernel_size=4, stride=2, padding=1) # What: Transpose conv for feature upsampling.
        # Why: Learned 2x upscale in feature branch.
        # How better: Kernel=4/stride=2 is standard for artifact-free up; better than PixelShuffle (simpler) or interp (learned filters capture patterns).
        self.residual = nn.Conv2d(64, 1, kernel_size=3, padding=1) # What: Conv to predict residual (1 channel).
        # Why: Sub-band residual for detail addition.
        # How better: Reduces to 1ch efficiently; better than direct predict (focuses on high-freq, pyramid advantage).
        self.up_image = nn.ConvTranspose2d(1, 1, kernel_size=4, stride=2, padding=1) # What: Transpose conv for image branch upsampling.
        # Why: Upscales current reconstruction.
        # How better: Parallel to features; kernel/stride same as up_feature for alignment, better than shared layer (branch-specific).
        self.global_up = nn.ConvTranspose2d(1, 1, kernel_size=4, stride=scale_factor, padding=0) # FIXED: Changed padding=1 to 0 to ensure output size = scale_factor * input_size (e.g., 4*128=512, not 510).
        # Why: Direct global upsampling from input.
        # How better: Stride=scale_factor (e.g., 4) for end-to-end skip; better than no global (stabilizes training, reduces error propagation).
    def forward(self, x):
        # What: Forward pass computing multi-scale outputs.
        # Why: Generates predictions at each level + final.
        # How better: Progressive upscale reduces hallucination; better than single-pass large deconv (less checkerboard artifacts).
        features = self.initial_conv(x) # What: Applies initial conv.
        # Why: Base feature extraction.
        # How better: Starts with rich reps; better than direct input use (learns low-level edges).
        for block in self.recursive_blocks: # What: Loops over blocks.
            # Why: Refines features recursively.
            # How better: Iterative refinement; better than one-pass deep (residuals prevent degradation).
            res = features # What: Stores residual.
            # Why: For local skip connection.
            # How better: Identity mapping; easier optimization than non-residual.
            features = block(features) # What: Applies block.
            # Why: Transforms features.
            # How better: Sequential call; clean over manual layer-by-layer.
            features = res + features # What: Adds residual.
            # Why: Local residual learning.
            # How better: Stabilizes gradients; better than plain add (prevents vanishing in depth).
       
        predictions = [] # What: List to store level outputs.
        # Why: For multi-scale supervision/loss.
        # How better: Enables deep supervision; improves training vs. final loss only.
        current = x # What: Initializes image branch with input.
        # Why: For progressive reconstruction.
        # How better: Starts from LR; builds up, better than all from features (preserves original signal).
        for level in range(self.pyramid_levels): # What: Loop over levels (e.g., 2).
            # Why: Handles each 2x step.
            # How better: Divide upscale; reduces complexity per step vs. one big upscale.
            up_f = self.up_feature(features) # What: Upsamples features.
            # Why: Prepares for level residual.
            # How better: Learned up; captures context better than fixed.
            res = self.residual(up_f) # What: Predicts residual.
            # Why: Adds details at this scale.
            # How better: Focuses on diffs; efficient for SR.
            up_i = self.up_image(current) # What: Upsamples current recon.
            # Why: Coarse up for addition.
            # How better: Separate branch; optimizes for image vs. features.
            recon = up_i + res # What: Reconstructs level.
            # Why: Combines coarse + detail.
            # How better: Residual recon; preserves info better than overwrite.
            predictions.append(recon) # What: Stores level pred.
            # Why: For supervision.
            # How better: Multi-loss; improves intermediates.
            current = recon # What: Updates for next level.
            # Why: Progressive build.
            # How better: Chains levels; accumulates accuracy.
            features = up_f # What: Updates features.
            # Why: Passes upsampled to next.
            # How better: Hierarchical; reuses refined feats.
        global_u = self.global_up(x) # What: Direct upscale from input.
        # Why: Global residual.
        # How better: Long skip; stabilizes end-to-end.
        output = global_u + predictions[-1] # What: Final output.
        # Why: Enhances with global.
        # How better: Combines paths; better than local only.
        return predictions + [output] # What: Returns all preds + final.
        # Why: For flexible loss (sum weighted).
        # How better: Enables training on intermediates; superior performance.

# %%
# Example Custom Dataset (adjust paths and loading as per your data)
class CustomSRDataset(Dataset):
    def __init__(self, lr_dir, hr_dir, transform=None, crop_size=None):
        # What: Dataset for paired LR/HR images.
        # Why: Loads CT slices for SR training.
        # How better: Handles variable sizes; optional crop for fixed patches.
        self.lr_dir = lr_dir
        self.hr_dir = hr_dir
        self.lr_files = sorted(os.listdir(lr_dir))
        self.transform = transform
        self.crop_size = crop_size  # Optional: (lr_crop_h, lr_crop_w) for random crops
    
    def __len__(self):
        return len(self.lr_files)
    
    def __getitem__(self, idx):
        lr_path = os.path.join(self.lr_dir, self.lr_files[idx])
        hr_path = os.path.join(self.hr_dir, self.lr_files[idx])  # Assume same filenames
        
        lr = Image.open(lr_path).convert('L')  # Grayscale
        hr = Image.open(hr_path).convert('L')
        
        if self.transform:
            lr = self.transform(lr)
            hr = self.transform(hr)
        
        # Optional random crop for fixed size (better for SR to avoid padding)
        if self.crop_size:
            crop_h, crop_w = self.crop_size
            max_i = lr.shape[1] - crop_h
            max_j = lr.shape[2] - crop_w
            i = torch.randint(0, max_i + 1, (1,)).item() if max_i >= 0 else 0
            j = torch.randint(0, max_j + 1, (1,)).item() if max_j >= 0 else 0
            lr = lr[:, i:i+crop_h, j:j+crop_w]
            # HR crop: scale_factor=4, so 4x larger crop
            hr_crop_h = crop_h * 4
            hr_crop_w = crop_w * 4
            hr_i = i * 4
            hr_j = j * 4
            hr = hr[:, hr_i:hr_i+hr_crop_h, hr_j:hr_j+hr_crop_w]
        
        return lr, hr

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import os
from PIL import Image  # For loading images; replace if using other formats

class CharbonnierLoss(nn.Module):
    # What: Defines Charbonnier loss for robust regression.
    # Why: Approximates L1 but differentiable; better for outliers in SR than MSE.
    # How better: epsilon prevents zero gradient issues; more stable than pure L1.
    def __init__(self, epsilon=1e-3):
        super(CharbonnierLoss, self).__init__()
        self.epsilon = epsilon
   
    def forward(self, pred, target):
        # What: Computes mean Charbonnier over batch.
        # Why: Pixel-wise robust diff.
        # How better: Mean reduces to scalar; works on variable sizes if shapes match.
        diff = pred - target
        loss = torch.mean(torch.sqrt(diff * diff + self.epsilon * self.epsilon))
        return loss

def pad_collate(batch):
    # What: Custom collate to pad variable-height images (widths assumed same).
    # Why: Fixes RuntimeError by making tensors stackable.
    # How better: Centers padding; preserves content vs. resizing (avoids distortion); zeros pad assumes black background.
    lrs, hrs = list(zip(*batch))
    
    # Pad LRs
    max_h_lr = max(lr.shape[1] for lr in lrs)  # shape[1]=H for [C,H,W]
    lrs_padded = []
    for lr in lrs:
        pad_top = (max_h_lr - lr.shape[1]) // 2
        pad_bottom = max_h_lr - lr.shape[1] - pad_top
        lrs_padded.append(F.pad(lr, (0, 0, pad_top, pad_bottom)))  # pad (left, right, top, bottom)
    
    # Pad HRs similarly
    max_h_hr = max(hr.shape[1] for hr in hrs)
    hrs_padded = []
    for hr in hrs:
        pad_top = (max_h_hr - hr.shape[1]) // 2
        pad_bottom = max_h_hr - hr.shape[1] - pad_top
        hrs_padded.append(F.pad(hr, (0, 0, pad_top, pad_bottom)))
    
    return torch.stack(lrs_padded), torch.stack(hrs_padded)


# Define transforms (normalize if needed, e.g., CT Hounsfield units)
transform = transforms.Compose([
    transforms.ToTensor(),
    # transforms.Normalize(mean=0.5, std=0.5)  # Uncomment if needed
])

# Create Dataset and DataLoader with collate_fn
train_dataset = CustomSRDataset(lr_dir='E:/Normal/train_lr', hr_dir='E:/Normal/train_hr', transform=transform, crop_size=(32, 128))  # Example crop: LR 32x128, HR 128x512; adjust
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, collate_fn=pad_collate)  # Use pad_collate; remove if using crop_size to make all fixed

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

lapsrn = LapSRN(scale_factor=4).to(device)

# Parameter check (should print ~1,056,194 as you saw)
print(f"Model has {sum(p.numel() for p in lapsrn.parameters())} parameters")

optimizer = torch.optim.Adam(lapsrn.parameters(), lr=1e-4)
criterion = CharbonnierLoss()
weights = [0.5, 1.0]  # For two intermediate levels (2x and 4x)
num_epochs = 5

for epoch in range(num_epochs):
    lapsrn.train()
    total_loss = 0
    for lr, hr in train_loader:
        lr, hr = lr.to(device), hr.to(device)
        predictions = lapsrn(lr)
       
        # Multi-scale loss
        loss = 0
        current_scale = 2  # Start at 2 for first level (2x)
        for i, pred in enumerate(predictions[:-1]):  # Intermediate levels
            target_size = (lr.shape[2] * current_scale, lr.shape[3] * current_scale)  # H, W
            target_resized = F.interpolate(
                hr,
                size=target_size,
                mode='bicubic',  # Better for images
                align_corners=False
            )
            loss += weights[i] * criterion(pred, target_resized)
            current_scale *= 2
       
        # Final output loss
        loss += criterion(predictions[-1], hr)
       
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
   
    avg_loss = total_loss / len(train_loader)
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}")

# Save model
torch.save(lapsrn.state_dict(), 'E:/Normal/models/lapsrn.pth')
# Out:
# Model has 990051 parameters
# Epoch [1/5], Loss: 0.1962
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 75
#      73 lapsrn.train()
#      74 total_loss = 0
# ---> 75 for lr, hr in train_loader:
#      76     lr, hr = lr.to(device), hr.to(device)
#      77     predictions = lapsrn(lr)
#
# File E:\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:732, in _BaseDataLoaderIter.__next__(self)
#     729 if self._sampler_iter is None:
#     730     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731     self._reset()  # type: ignore[call-arg]
# --> 732 data = self._next_data()
#     733 self._num_yielded += 1
#     734 if (
#     735     self._dataset_kind == _DatasetKind.Iterable
#     736     and self._IterableDataset_len_called is not None
#     737     and self._num_yielded > self._IterableDataset_len_called
#     738 ):
#
# File E:\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:788, in _SingleProcessDataLoaderIter._next_data(self)
#     786 def _next_data(self):
#     787     index = self._next_index()  # may raise StopIteration
# --> 788     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     789     if self._pin_memory:
#     790         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File E:\anaconda3\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# Cell In[8], line 21, in CustomSRDataset.__getitem__(self, idx)
#      18 hr_path = os.path.join(self.hr_dir, self.lr_files[idx])  # Assume same filenames
#      20 lr = Image.open(lr_path).convert('L')  # Grayscale
# ---> 21 hr = Image.open(hr_path).convert('L')
#      23 if self.transform:
#      24     lr = self.transform(lr)
#
# File E:\anaconda3\Lib\site-packages\PIL\Image.py:3493, in open(fp, mode, formats)
#    3491 if is_path(fp):
#    3492     filename = os.fspath(fp)
# -> 3493     fp = builtins.open(filename, "rb")
#    3494     exclusive_fp = True
#    3495 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:/Normal/train_hr\\10130.png'
